# %%
import torch
print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("GPU:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")
# Out:
# Torch version: 2.4.1
# CUDA available: True
# GPU: NVIDIA GeForce RTX 3050 Laptop GPU

# %%
from monai.utils import first
import matplotlib.pyplot as plt
import torch
import os
import numpy as np
from monai.losses import DiceLoss
from tqdm import tqdm

# %%
def dice_metric(predicted, target):
    dice_value = DiceLoss(to_onehot_y=True, sigmoid=True, squared_pred=True)
    value = 1 - dice_value(predicted, target).item()
    return value

# %%
def calculate_weights(val1, val2):
    count = np.array([val1, val2])
    summ = count.sum()
    weights = count/summ
    weights = 1/weights
    summ = weights.sum()
    weights = weights/summ
    return torch.tensor(weights, dtype=torch.float32)

# %%
def train(model, data_in, loss, optim, max_epochs, model_dir, test_interval=1 , device=torch.device("cuda:0")):
    best_metric = -1
    best_metric_epoch = -1
    save_loss_train = []
    save_loss_test = []
    save_metric_train = []
    save_metric_test = []
    train_loader, test_loader = data_in

    for epoch in range(max_epochs):
        print("-" * 10)
        print(f"epoch {epoch + 1}/{max_epochs}")
        model.train()
        train_epoch_loss = 0
        train_step = 0
        epoch_metric_train = 0
        for batch_data in train_loader:
            
            train_step += 1

            volume = batch_data["vol"]
            label = batch_data["seg"]
            label = label != 0
            volume, label = (volume.to(device), label.to(device))

            optim.zero_grad()
            outputs = model(volume)
            
            train_loss = loss(outputs, label)
            
            train_loss.backward()
            optim.step()

            train_epoch_loss += train_loss.item()
            print(
                f"{train_step}/{len(train_loader) // train_loader.batch_size}, "
                f"Train_loss: {train_loss.item():.4f}")

            train_metric = dice_metric(outputs, label)
            epoch_metric_train += train_metric
            print(f'Train_dice: {train_metric:.4f}')

        print('-'*20)
        
        train_epoch_loss /= train_step
        print(f'Epoch_loss: {train_epoch_loss:.4f}')
        save_loss_train.append(train_epoch_loss)
        np.save(os.path.join(model_dir, 'loss_train.npy'), save_loss_train)
        
        epoch_metric_train /= train_step
        print(f'Epoch_metric: {epoch_metric_train:.4f}')

        save_metric_train.append(epoch_metric_train)
        np.save(os.path.join(model_dir, 'metric_train.npy'), save_metric_train)

        if (epoch + 1) % test_interval == 0:

            model.eval()
            with torch.no_grad():
                test_epoch_loss = 0
                test_metric = 0
                epoch_metric_test = 0
                test_step = 0

                for test_data in test_loader:

                    test_step += 1

                    test_volume = test_data["vol"]
                    test_label = test_data["seg"]
                    test_label = test_label != 0
                    test_volume, test_label = (test_volume.to(device), test_label.to(device),)
                    
                    test_outputs = model(test_volume)
                    
                    test_loss = loss(test_outputs, test_label)
                    test_epoch_loss += test_loss.item()
                    test_metric = dice_metric(test_outputs, test_label)
                    epoch_metric_test += test_metric
                    
                
                test_epoch_loss /= test_step
                print(f'test_loss_epoch: {test_epoch_loss:.4f}')
                save_loss_test.append(test_epoch_loss)
                np.save(os.path.join(model_dir, 'loss_test.npy'), save_loss_test)

                epoch_metric_test /= test_step
                print(f'test_dice_epoch: {epoch_metric_test:.4f}')
                save_metric_test.append(epoch_metric_test)
                np.save(os.path.join(model_dir, 'metric_test.npy'), save_metric_test)

                if epoch_metric_test > best_metric:
                    best_metric = epoch_metric_test
                    best_metric_epoch = epoch + 1
                    torch.save(model.state_dict(), os.path.join(
                        model_dir, "best_metric_model.pth"))
                
                print(
                    f"current epoch: {epoch + 1} current mean dice: {test_metric:.4f}"
                    f"\nbest mean dice: {best_metric:.4f} "
                    f"at epoch: {best_metric_epoch}"
                )


    print(
        f"train completed, best_metric: {best_metric:.4f} "
        f"at epoch: {best_metric_epoch}")

# %%
def calculate_pixels(data):
    val = np.zeros((1, 2))

    for batch in tqdm(data):
        batch_label = batch["seg"] != 0
        _, count = np.unique(batch_label, return_counts=True)

        if len(count) == 1:
            count = np.append(count, 0)
        val += count

    print('The last values:', val)
    return val

# %%
def prepare(in_dir, pixdim=(1.5, 1.5, 1.0), a_min=-200, a_max=200, spatial_size=[128, 128, 64], cache=True):
    set_determinism(seed=0)

    path_train_volumes = sorted(glob(os.path.join(in_dir, "TrainVolumes", "*.nii.gz")))
    path_train_segmentation = sorted(glob(os.path.join(in_dir, "TrainSegmentation", "*.nii.gz")))

    path_test_volumes = sorted(glob(os.path.join(in_dir, "TestVolumes", "*.nii.gz")))
    path_test_segmentation = sorted(glob(os.path.join(in_dir, "TestSegmentation", "*.nii.gz")))

    train_files = [{"vol": image_name, "seg": label_name} for image_name, label_name in
                   zip(path_train_volumes, path_train_segmentation)]
    test_files = [{"vol": image_name, "seg": label_name} for image_name, label_name in
                  zip(path_test_volumes, path_test_segmentation)]

    train_transforms = Compose(
        [
            LoadImaged(keys=["vol", "seg"]),
            EnsureChannelFirstD(keys=["vol", "seg"]),
            Spacingd(keys=["vol", "seg"], pixdim=pixdim, mode=("bilinear", "nearest")),
            Orientationd(keys=["vol", "seg"], axcodes="RAS"),
            ScaleIntensityRanged(keys=["vol"], a_min=a_min, a_max=a_max, b_min=0.0, b_max=1.0, clip=True),
            CropForegroundd(keys=["vol", "seg"], source_key="vol"),
            Resized(keys=["vol", "seg"], spatial_size=spatial_size),
            ToTensord(keys=["vol", "seg"]),

        ]
    )

    test_transforms = Compose(
        [
            LoadImaged(keys=["vol", "seg"]),
            EnsureChannelFirstD(keys=["vol", "seg"]),
            Spacingd(keys=["vol", "seg"], pixdim=pixdim, mode=("bilinear", "nearest")),
            Orientationd(keys=["vol", "seg"], axcodes="RAS"),
            ScaleIntensityRanged(keys=["vol"], a_min=a_min, a_max=a_max, b_min=0.0, b_max=1.0, clip=True),
            CropForegroundd(keys=['vol', 'seg'], source_key='vol'),
            Resized(keys=["vol", "seg"], spatial_size=spatial_size),
            ToTensord(keys=["vol", "seg"]),

        ]
    )

    if cache:
        train_ds = CacheDataset(data=train_files, transform=train_transforms, cache_rate=1.0)
        train_loader = DataLoader(train_ds, batch_size=1)

        test_ds = CacheDataset(data=test_files, transform=test_transforms, cache_rate=1.0)
        test_loader = DataLoader(test_ds, batch_size=1)

        return train_loader, test_loader

    else:
        train_ds = Dataset(data=train_files, transform=train_transforms)
        train_loader = DataLoader(train_ds, batch_size=1)

        test_ds = Dataset(data=test_files, transform=test_transforms)
        test_loader = DataLoader(test_ds, batch_size=1)

        return train_loader, test_loader

# %%
from monai.networks.nets import UNet
from monai.networks.layers import Norm
from monai.losses import DiceLoss, DiceCELoss
import os
from monai.transforms import (
    Compose,
    EnsureChannelFirstD,
    LoadImaged,
    Resized,
    ToTensord,
    Spacingd,
    Orientationd,
    ScaleIntensityRanged,
    CropForegroundd,

)
from monai.data import DataLoader, Dataset, CacheDataset
from monai.utils import set_determinism
from glob import glob 
import torch

# %%
data_dir = 'D:/monai/dataset/final_/'
model_dir = 'D:/monai/results_/results' 
data_in = prepare(data_dir, cache=False)

# %%
# Define your device: CUDA if available, otherwise CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
from monai.networks.nets import UNet
from monai.networks.layers import Norm
import torch

device = torch.device("cuda")
model = UNet(
    spatial_dims=3,  
    in_channels=1,
    out_channels=2,
    channels=(16, 32, 64, 128, 256),
    strides=(2, 2, 2, 2),
    num_res_units=2,
    norm=Norm.BATCH,
).to(device)

# %%
def calculate_accuracy(output, target):
    # Convert the predicted output to binary (0 or 1) using a threshold (0.5)
    output = torch.sigmoid(output)  # Use sigmoid if it's not done in the model
    predicted = (output > 0.5).float()  # Thresholding at 0.5 for binary classification

    # Compute the number of correct predictions
    correct = (predicted == target).float().sum()
    
    # Total number of pixels
    total = torch.numel(target)
    
    # Accuracy as the percentage of correctly classified pixels
    accuracy = correct / total
    return accuracy.item()

# %%
#loss_function = DiceCELoss(to_onehot_y=True, sigmoid=True, squared_pred=True, ce_weight=calculate_weights(1792651250,2510860).to(device))
loss_function = DiceLoss(to_onehot_y=True, sigmoid=True, squared_pred=True)
optimizer = torch.optim.Adam(model.parameters(), 1e-5, weight_decay=1e-5, amsgrad=True)

if __name__ == '__main__':
    train(model, data_in, loss_function, optimizer, 120, model_dir)
# Out:
# ----------
# epoch 1/120
# 1/172, Train_loss: 0.5403
# Train_dice: 0.4597
# 2/172, Train_loss: 0.4791
# Train_dice: 0.5209
# 3/172, Train_loss: 0.4364
# Train_dice: 0.5636
# 4/172, Train_loss: 0.5577
# Train_dice: 0.4423
# 5/172, Train_loss: 0.4567
# Train_dice: 0.5433
# 6/172, Train_loss: 0.4159
# Train_dice: 0.5841
# 7/172, Train_loss: 0.5014
# Train_dice: 0.4986
# 8/172, Train_loss: 0.5765
# Train_dice: 0.4235
# 9/172, Train_loss: 0.5339
# Train_dice: 0.4661
# 10/172, Train_loss: 0.4882
# Train_dice: 0.5118
# 11/172, Train_loss: 0.5383
# Train_dice: 0.4617
# 12/172, Train_loss: 0.4651
# Train_dice: 0.5349
# 13/172, Train_loss: 0.5603
# Train_dice: 0.4397
# 14/172, Train_loss: 0.4649
# Train_dice: 0.5351
# 15/172, Train_loss: 0.4693
# Train_dice: 0.5307
# 16/172, Train_loss: 0.5720
# Train_dice: 0.4280
# 17/172, Train_loss: 0.4705
# Train_dice: 0.5295
# 18/172, Train_loss: 0.5239
# Train_dice: 0.4761
# 19/172, Train_loss: 0.4446
# Train_dice: 0.5554
# 20/172, Train_loss: 0.5126
# Train_dice: 0.4874
# 21/172, Train_loss: 0.5958
# Train_dice: 0.4042
# 22/172, Train_loss: 0.4310
# Train_dice: 0.5690
# 23/172, Train_loss: 0.4846
# Train_dice: 0.5154
# 24/172, Train_loss: 0.5855
# Train_dice: 0.4145
# 25/172, Train_loss: 0.5794
# Train_dice: 0.4206
# 26/172, Train_loss: 0.4711
# Train_dice: 0.5289
# 27/172, Train_loss: 0.5175
# Train_dice: 0.4825
# 28/172, Train_loss: 0.5954
# Train_dice: 0.4046
# 29/172, Train_loss: 0.5790
# Train_dice: 0.4210
# 30/172, Train_loss: 0.4302
# Train_dice: 0.5698
# 31/172, Train_loss: 0.5034
# Train_dice: 0.4966
# 32/172, Train_loss: 0.5966
# Train_dice: 0.4034
# 33/172, Train_loss: 0.5542
# Train_dice: 0.4458
# 34/172, Train_loss: 0.5650
# Train_dice: 0.4350
# 35/172, Train_loss: 0.4336
# Train_dice: 0.5664
# 36/172, Train_loss: 0.5043
# Train_dice: 0.4957
# 37/172, Train_loss: 0.4593
# Train_dice: 0.5407
# 38/172, Train_loss: 0.4910
# Train_dice: 0.5090
# 39/172, Train_loss: 0.5763
# Train_dice: 0.4237
# 40/172, Train_loss: 0.4773
# Train_dice: 0.5227
# 41/172, Train_loss: 0.5009
# Train_dice: 0.4991
# 42/172, Train_loss: 0.4908
# Train_dice: 0.5092
# 43/172, Train_loss: 0.5305
# Train_dice: 0.4695
# 44/172, Train_loss: 0.5123
# Train_dice: 0.4877
# 45/172, Train_loss: 0.5882
# Train_dice: 0.4118
# 46/172, Train_loss: 0.5485
# Train_dice: 0.4515
# 47/172, Train_loss: 0.4538
# Train_dice: 0.5462
# 48/172, Train_loss: 0.5292
# Train_dice: 0.4708
# 49/172, Train_loss: 0.5897
# Train_dice: 0.4103
# 50/172, Train_loss: 0.4480
# Train_dice: 0.5520
# 51/172, Train_loss: 0.4715
# Train_dice: 0.5285
# 52/172, Train_loss: 0.5530
# Train_dice: 0.4470
# 53/172, Train_loss: 0.4257
# Train_dice: 0.5743
# 54/172, Train_loss: 0.4825
# Train_dice: 0.5175
# 55/172, Train_loss: 0.5710
# Train_dice: 0.4290
# 56/172, Train_loss: 0.4274
# Train_dice: 0.5726
# 57/172, Train_loss: 0.5062
# Train_dice: 0.4938
# 58/172, Train_loss: 0.4734
# Train_dice: 0.5266
# 59/172, Train_loss: 0.5375
# Train_dice: 0.4625
# 60/172, Train_loss: 0.4396
# Train_dice: 0.5604
# 61/172, Train_loss: 0.5776
# Train_dice: 0.4224
# 62/172, Train_loss: 0.4499
# Train_dice: 0.5501
# 63/172, Train_loss: 0.4518
# Train_dice: 0.5482
# 64/172, Train_loss: 0.5243
# Train_dice: 0.4757
# 65/172, Train_loss: 0.5689
# Train_dice: 0.4311
# 66/172, Train_loss: 0.4405
# Train_dice: 0.5595
# 67/172, Train_loss: 0.5625
# Train_dice: 0.4375
# 68/172, Train_loss: 0.5435
# Train_dice: 0.4565
# 69/172, Train_loss: 0.4308
# Train_dice: 0.5692
# 70/172, Train_loss: 0.4671
# Train_dice: 0.5329
# 71/172, Train_loss: 0.4398
# Train_dice: 0.5602
# 72/172, Train_loss: 0.5077
# Train_dice: 0.4923
# 73/172, Train_loss: 0.5155
# Train_dice: 0.4845
# 74/172, Train_loss: 0.5507
# Train_dice: 0.4493
# 75/172, Train_loss: 0.5855
# Train_dice: 0.4145
# 76/172, Train_loss: 0.4245
# Train_dice: 0.5755
# 77/172, Train_loss: 0.4708
# Train_dice: 0.5292
# 78/172, Train_loss: 0.5292
# Train_dice: 0.4708
# 79/172, Train_loss: 0.4627
# Train_dice: 0.5373
# 80/172, Train_loss: 0.5509
# Train_dice: 0.4491
# 81/172, Train_loss: 0.4134
# Train_dice: 0.5866
# 82/172, Train_loss: 0.3946
# Train_dice: 0.6054
# 83/172, Train_loss: 0.4996
# Train_dice: 0.5004
# 84/172, Train_loss: 0.5910
# Train_dice: 0.4090
# 85/172, Train_loss: 0.5744
# Train_dice: 0.4256
# 86/172, Train_loss: 0.5681
# Train_dice: 0.4319
# 87/172, Train_loss: 0.5783
# Train_dice: 0.4217
# 88/172, Train_loss: 0.5684
# Train_dice: 0.4316
# 89/172, Train_loss: 0.5779
# Train_dice: 0.4221
# 90/172, Train_loss: 0.4378
# Train_dice: 0.5622
# 91/172, Train_loss: 0.5028
# Train_dice: 0.4972
# 92/172, Train_loss: 0.5564
# Train_dice: 0.4436
# 93/172, Train_loss: 0.4753
# Train_dice: 0.5247
# 94/172, Train_loss: 0.5926
# Train_dice: 0.4074
# 95/172, Train_loss: 0.5210
# Train_dice: 0.4790
# 96/172, Train_loss: 0.4653
# Train_dice: 0.5347
# 97/172, Train_loss: 0.5608
# Train_dice: 0.4392
# 98/172, Train_loss: 0.5843
# Train_dice: 0.4157
# 99/172, Train_loss: 0.5025
# Train_dice: 0.4975
# 100/172, Train_loss: 0.4078
# Train_dice: 0.5922
# 101/172, Train_loss: 0.5430
# Train_dice: 0.4570
# 102/172, Train_loss: 0.5246
# Train_dice: 0.4754
# 103/172, Train_loss: 0.5135
# Train_dice: 0.4865
# 104/172, Train_loss: 0.5186
# Train_dice: 0.4814
# 105/172, Train_loss: 0.5203
# Train_dice: 0.4797
# 106/172, Train_loss: 0.5172
# Train_dice: 0.4828
# 107/172, Train_loss: 0.4248
# Train_dice: 0.5752
# 108/172, Train_loss: 0.5934
# Train_dice: 0.4066
# 109/172, Train_loss: 0.5170
# Train_dice: 0.4830
# 110/172, Train_loss: 0.5795
# Train_dice: 0.4205
# 111/172, Train_loss: 0.5308
# Train_dice: 0.4692
# 112/172, Train_loss: 0.4367
# Train_dice: 0.5633
# 113/172, Train_loss: 0.5119
# Train_dice: 0.4881
# 114/172, Train_loss: 0.4428
# Train_dice: 0.5572
# 115/172, Train_loss: 0.5006
# Train_dice: 0.4994
# 116/172, Train_loss: 0.4197
# Train_dice: 0.5803
# 117/172, Train_loss: 0.4622
# Train_dice: 0.5378
# 118/172, Train_loss: 0.3526
# Train_dice: 0.6474
# 119/172, Train_loss: 0.4533
# Train_dice: 0.5467
# 120/172, Train_loss: 0.4398
# Train_dice: 0.5602
# 121/172, Train_loss: 0.4363
# Train_dice: 0.5637
# 122/172, Train_loss: 0.5647
# Train_dice: 0.4353
# 123/172, Train_loss: 0.4677
# Train_dice: 0.5323
# 124/172, Train_loss: 0.3857
# Train_dice: 0.6143
# 125/172, Train_loss: 0.4688
# Train_dice: 0.5312
# 126/172, Train_loss: 0.5633
# Train_dice: 0.4367
# 127/172, Train_loss: 0.4478
# Train_dice: 0.5522
# 128/172, Train_loss: 0.3835
# Train_dice: 0.6165
# 129/172, Train_loss: 0.4881
# Train_dice: 0.5119
# 130/172, Train_loss: 0.4132
# Train_dice: 0.5868
# 131/172, Train_loss: 0.5612
# Train_dice: 0.4388
# 132/172, Train_loss: 0.5182
# Train_dice: 0.4818
# 133/172, Train_loss: 0.4207
# Train_dice: 0.5793
# 134/172, Train_loss: 0.5265
# Train_dice: 0.4735
# 135/172, Train_loss: 0.3945
# Train_dice: 0.6055
# 136/172, Train_loss: 0.5262
# Train_dice: 0.4738
# 137/172, Train_loss: 0.5278
# Train_dice: 0.4722
# 138/172, Train_loss: 0.4135
# Train_dice: 0.5865
# 139/172, Train_loss: 0.5159
# Train_dice: 0.4841
# 140/172, Train_loss: 0.4852
# Train_dice: 0.5148
# 141/172, Train_loss: 0.5408
# Train_dice: 0.4592
# 142/172, Train_loss: 0.5681
# Train_dice: 0.4319
# 143/172, Train_loss: 0.4193
# Train_dice: 0.5807
# 144/172, Train_loss: 0.4668
# Train_dice: 0.5332
# 145/172, Train_loss: 0.3816
# Train_dice: 0.6184
# 146/172, Train_loss: 0.5828
# Train_dice: 0.4172
# 147/172, Train_loss: 0.4160
# Train_dice: 0.5840
# 148/172, Train_loss: 0.3759
# Train_dice: 0.6241
# 149/172, Train_loss: 0.5295
# Train_dice: 0.4705
# 150/172, Train_loss: 0.5824
# Train_dice: 0.4176
# 151/172, Train_loss: 0.5163
# Train_dice: 0.4837
# 152/172, Train_loss: 0.4255
# Train_dice: 0.5745
# 153/172, Train_loss: 0.4792
# Train_dice: 0.5208
# 154/172, Train_loss: 0.5863
# Train_dice: 0.4137
# 155/172, Train_loss: 0.5276
# Train_dice: 0.4724
# 156/172, Train_loss: 0.3987
# Train_dice: 0.6013
# 157/172, Train_loss: 0.5083
# Train_dice: 0.4917
# 158/172, Train_loss: 0.5841
# Train_dice: 0.4159
# 159/172, Train_loss: 0.5207
# Train_dice: 0.4793
# 160/172, Train_loss: 0.4515
# Train_dice: 0.5485
# 161/172, Train_loss: 0.3680
# Train_dice: 0.6320
# 162/172, Train_loss: 0.4105
# Train_dice: 0.5895
# 163/172, Train_loss: 0.5740
# Train_dice: 0.4260
# 164/172, Train_loss: 0.4483
# Train_dice: 0.5517
# 165/172, Train_loss: 0.3641
# Train_dice: 0.6359
# 166/172, Train_loss: 0.4492
# Train_dice: 0.5508
# 167/172, Train_loss: 0.4550
# Train_dice: 0.5450
# 168/172, Train_loss: 0.3623
# Train_dice: 0.6377
# 169/172, Train_loss: 0.5154
# Train_dice: 0.4846
# 170/172, Train_loss: 0.3776
# Train_dice: 0.6224
# 171/172, Train_loss: 0.5233
# Train_dice: 0.4767
# 172/172, Train_loss: 0.4332
# Train_dice: 0.5668
# --------------------
# Epoch_loss: 0.4965
# Epoch_metric: 0.5035
# test_loss_epoch: 0.4494
# test_dice_epoch: 0.5506
# current epoch: 1 current mean dice: 0.4914
# best mean dice: 0.5506 at epoch: 1
# ----------
# epoch 2/120
# 1/172, Train_loss: 0.5028
# Train_dice: 0.4972
# 2/172, Train_loss: 0.4158
# Train_dice: 0.5842
# 3/172, Train_loss: 0.3608
# Train_dice: 0.6392
# 4/172, Train_loss: 0.5320
# Train_dice: 0.4680
# 5/172, Train_loss: 0.3947
# Train_dice: 0.6053
# 6/172, Train_loss: 0.3367
# Train_dice: 0.6633
# 7/172, Train_loss: 0.4476
# Train_dice: 0.5524
# 8/172, Train_loss: 0.5591
# Train_dice: 0.4409
# 9/172, Train_loss: 0.4889
# Train_dice: 0.5111
# 10/172, Train_loss: 0.4268
# Train_dice: 0.5732
# 11/172, Train_loss: 0.4978
# Train_dice: 0.5022
# 12/172, Train_loss: 0.4033
# Train_dice: 0.5967
# 13/172, Train_loss: 0.5320
# Train_dice: 0.4680
# 14/172, Train_loss: 0.3963
# Train_dice: 0.6037
# 15/172, Train_loss: 0.4055
# Train_dice: 0.5945
# 16/172, Train_loss: 0.5492
# Train_dice: 0.4508
# 17/172, Train_loss: 0.4056
# Train_dice: 0.5944
# 18/172, Train_loss: 0.4858
# Train_dice: 0.5142
# 19/172, Train_loss: 0.3777
# Train_dice: 0.6223
# 20/172, Train_loss: 0.4801
# Train_dice: 0.5199
# 21/172, Train_loss: 0.5831
# Train_dice: 0.4169
# 22/172, Train_loss: 0.3575
# Train_dice: 0.6425
# 23/172, Train_loss: 0.4245
# Train_dice: 0.5755
# 24/172, Train_loss: 0.5683
# Train_dice: 0.4317
# 25/172, Train_loss: 0.5576
# Train_dice: 0.4424
# 26/172, Train_loss: 0.4044
# Train_dice: 0.5956
# 27/172, Train_loss: 0.4670
# Train_dice: 0.5330
# 28/172, Train_loss: 0.5820
# Train_dice: 0.4180
# 29/172, Train_loss: 0.5580
# Train_dice: 0.4420
# 30/172, Train_loss: 0.3540
# Train_dice: 0.6460
# 31/172, Train_loss: 0.4528
# Train_dice: 0.5472
# 32/172, Train_loss: 0.5859
# Train_dice: 0.4141
# 33/172, Train_loss: 0.5216
# Train_dice: 0.4784
# 34/172, Train_loss: 0.5371
# Train_dice: 0.4629
# 35/172, Train_loss: 0.3572
# Train_dice: 0.6428
# 36/172, Train_loss: 0.4532
# Train_dice: 0.5468
# 37/172, Train_loss: 0.3916
# Train_dice: 0.6084
# 38/172, Train_loss: 0.4355
# Train_dice: 0.5645
# 39/172, Train_loss: 0.5540
# Train_dice: 0.4460
# 40/172, Train_loss: 0.4182
# Train_dice: 0.5818
# 41/172, Train_loss: 0.4527
# Train_dice: 0.5473
# 42/172, Train_loss: 0.4346
# Train_dice: 0.5654
# 43/172, Train_loss: 0.4904
# Train_dice: 0.5096
# 44/172, Train_loss: 0.4647
# Train_dice: 0.5353
# 45/172, Train_loss: 0.5713
# Train_dice: 0.4287
# 46/172, Train_loss: 0.5133
# Train_dice: 0.4867
# 47/172, Train_loss: 0.3868
# Train_dice: 0.6132
# 48/172, Train_loss: 0.4859
# Train_dice: 0.5141
# 49/172, Train_loss: 0.5735
# Train_dice: 0.4265
# 50/172, Train_loss: 0.3802
# Train_dice: 0.6198
# 51/172, Train_loss: 0.4108
# Train_dice: 0.5892
# 52/172, Train_loss: 0.5341
# Train_dice: 0.4659
# 53/172, Train_loss: 0.3715
# Train_dice: 0.6285
# 54/172, Train_loss: 0.4377
# Train_dice: 0.5623
# 55/172, Train_loss: 0.5471
# Train_dice: 0.4529
# 56/172, Train_loss: 0.3582
# Train_dice: 0.6418
# 57/172, Train_loss: 0.4607
# Train_dice: 0.5393
# 58/172, Train_loss: 0.4160
# Train_dice: 0.5840
# 59/172, Train_loss: 0.5019
# Train_dice: 0.4981
# 60/172, Train_loss: 0.3764
# Train_dice: 0.6236
# 61/172, Train_loss: 0.5625
# Train_dice: 0.4375
# 62/172, Train_loss: 0.3889
# Train_dice: 0.6111
# 63/172, Train_loss: 0.3941
# Train_dice: 0.6059
# 64/172, Train_loss: 0.4865
# Train_dice: 0.5135
# 65/172, Train_loss: 0.5533
# Train_dice: 0.4467
# 66/172, Train_loss: 0.3811
# Train_dice: 0.6189
# 67/172, Train_loss: 0.5410
# Train_dice: 0.4590
# 68/172, Train_loss: 0.5209
# Train_dice: 0.4791
# 69/172, Train_loss: 0.3721
# Train_dice: 0.6279
# 70/172, Train_loss: 0.4135
# Train_dice: 0.5865
# 71/172, Train_loss: 0.3794
# Train_dice: 0.6206
# 72/172, Train_loss: 0.4652
# Train_dice: 0.5348
# 73/172, Train_loss: 0.4816
# Train_dice: 0.5184
# 74/172, Train_loss: 0.5250
# Train_dice: 0.4750
# 75/172, Train_loss: 0.5757
# Train_dice: 0.4243
# 76/172, Train_loss: 0.3680
# Train_dice: 0.6320
# 77/172, Train_loss: 0.4209
# Train_dice: 0.5791
# 78/172, Train_loss: 0.4944
# Train_dice: 0.5056
# 79/172, Train_loss: 0.4106
# Train_dice: 0.5894
# 80/172, Train_loss: 0.5389
# Train_dice: 0.4611
# 81/172, Train_loss: 0.3587
# Train_dice: 0.6413
# 82/172, Train_loss: 0.3347
# Train_dice: 0.6653
# 83/172, Train_loss: 0.4563
# Train_dice: 0.5437
# 84/172, Train_loss: 0.5805
# Train_dice: 0.4195
# 85/172, Train_loss: 0.5629
# Train_dice: 0.4371
# 86/172, Train_loss: 0.5604
# Train_dice: 0.4396
# 87/172, Train_loss: 0.5729
# Train_dice: 0.4271
# 88/172, Train_loss: 0.5609
# Train_dice: 0.4391
# 89/172, Train_loss: 0.5653
# Train_dice: 0.4347
# 90/172, Train_loss: 0.3882
# Train_dice: 0.6118
# 91/172, Train_loss: 0.4600
# Train_dice: 0.5400
# 92/172, Train_loss: 0.5332
# Train_dice: 0.4668
# 93/172, Train_loss: 0.4255
# Train_dice: 0.5745
# 94/172, Train_loss: 0.5823
# Train_dice: 0.4177
# 95/172, Train_loss: 0.4835
# Train_dice: 0.5165
# 96/172, Train_loss: 0.4183
# Train_dice: 0.5817
# 97/172, Train_loss: 0.5389
# Train_dice: 0.4611
# 98/172, Train_loss: 0.5753
# Train_dice: 0.4247
# 99/172, Train_loss: 0.4702
# Train_dice: 0.5298
# 100/172, Train_loss: 0.3488
# Train_dice: 0.6512
# 101/172, Train_loss: 0.5135
# Train_dice: 0.4865
# 102/172, Train_loss: 0.4919
# Train_dice: 0.5081
# 103/172, Train_loss: 0.4738
# Train_dice: 0.5262
# 104/172, Train_loss: 0.4831
# Train_dice: 0.5169
# 105/172, Train_loss: 0.4849
# Train_dice: 0.5151
# 106/172, Train_loss: 0.4820
# Train_dice: 0.5180
# 107/172, Train_loss: 0.3804
# Train_dice: 0.6196
# 108/172, Train_loss: 0.5870
# Train_dice: 0.4130
# 109/172, Train_loss: 0.4801
# Train_dice: 0.5199
# 110/172, Train_loss: 0.5679
# Train_dice: 0.4321
# 111/172, Train_loss: 0.4992
# Train_dice: 0.5008
# 112/172, Train_loss: 0.3879
# Train_dice: 0.6121
# 113/172, Train_loss: 0.4762
# Train_dice: 0.5238
# 114/172, Train_loss: 0.3924
# Train_dice: 0.6076
# 115/172, Train_loss: 0.4639
# Train_dice: 0.5361
# 116/172, Train_loss: 0.3678
# Train_dice: 0.6322
# 117/172, Train_loss: 0.4195
# Train_dice: 0.5805
# 118/172, Train_loss: 0.2939
# Train_dice: 0.7061
# 119/172, Train_loss: 0.4070
# Train_dice: 0.5930
# 120/172, Train_loss: 0.3919
# Train_dice: 0.6081
# 121/172, Train_loss: 0.3899
# Train_dice: 0.6101
# 122/172, Train_loss: 0.5466
# Train_dice: 0.4534
# 123/172, Train_loss: 0.4247
# Train_dice: 0.5753
# 124/172, Train_loss: 0.3290
# Train_dice: 0.6710
# 125/172, Train_loss: 0.4277
# Train_dice: 0.5723
# 126/172, Train_loss: 0.5453
# Train_dice: 0.4547
# 127/172, Train_loss: 0.4030
# Train_dice: 0.5970
# 128/172, Train_loss: 0.3288
# Train_dice: 0.6712
# 129/172, Train_loss: 0.4501
# Train_dice: 0.5499
# 130/172, Train_loss: 0.3636
# Train_dice: 0.6364
# 131/172, Train_loss: 0.5425
# Train_dice: 0.4575
# 132/172, Train_loss: 0.4883
# Train_dice: 0.5117
# 133/172, Train_loss: 0.3753
# Train_dice: 0.6247
# 134/172, Train_loss: 0.4998
# Train_dice: 0.5002
# 135/172, Train_loss: 0.3459
# Train_dice: 0.6541
# 136/172, Train_loss: 0.5011
# Train_dice: 0.4989
# 137/172, Train_loss: 0.4996
# Train_dice: 0.5004
# 138/172, Train_loss: 0.3693
# Train_dice: 0.6307
# 139/172, Train_loss: 0.4877
# Train_dice: 0.5123
# 140/172, Train_loss: 0.4488
# Train_dice: 0.5512
# 141/172, Train_loss: 0.5158
# Train_dice: 0.4842
# 142/172, Train_loss: 0.5513
# Train_dice: 0.4487
# 143/172, Train_loss: 0.3767
# Train_dice: 0.6233
# 144/172, Train_loss: 0.4288
# Train_dice: 0.5712
# 145/172, Train_loss: 0.3347
# Train_dice: 0.6653
# 146/172, Train_loss: 0.5713
# Train_dice: 0.4287
# 147/172, Train_loss: 0.3715
# Train_dice: 0.6285
# 148/172, Train_loss: 0.3292
# Train_dice: 0.6708
# 149/172, Train_loss: 0.5057
# Train_dice: 0.4943
# 150/172, Train_loss: 0.5729
# Train_dice: 0.4271
# 151/172, Train_loss: 0.4910
# Train_dice: 0.5090
# 152/172, Train_loss: 0.3834
# Train_dice: 0.6166
# 153/172, Train_loss: 0.4463
# Train_dice: 0.5537
# 154/172, Train_loss: 0.5766
# Train_dice: 0.4234
# 155/172, Train_loss: 0.5032
# Train_dice: 0.4968
# 156/172, Train_loss: 0.3541
# Train_dice: 0.6459
# 157/172, Train_loss: 0.4810
# Train_dice: 0.5190
# 158/172, Train_loss: 0.5745
# Train_dice: 0.4255
# 159/172, Train_loss: 0.4950
# Train_dice: 0.5050
# 160/172, Train_loss: 0.4150
# Train_dice: 0.5850
# 161/172, Train_loss: 0.3203
# Train_dice: 0.6797
# 162/172, Train_loss: 0.3682
# Train_dice: 0.6318
# 163/172, Train_loss: 0.5607
# Train_dice: 0.4393
# 164/172, Train_loss: 0.4118
# Train_dice: 0.5882
# 165/172, Train_loss: 0.3157
# Train_dice: 0.6843
# 166/172, Train_loss: 0.4123
# Train_dice: 0.5877
# 167/172, Train_loss: 0.4204
# Train_dice: 0.5796
# 168/172, Train_loss: 0.3171
# Train_dice: 0.6829
# 169/172, Train_loss: 0.4889
# Train_dice: 0.5111
# 170/172, Train_loss: 0.3348
# Train_dice: 0.6652
# 171/172, Train_loss: 0.4986
# Train_dice: 0.5014
# 172/172, Train_loss: 0.3977
# Train_dice: 0.6023
# --------------------
# Epoch_loss: 0.4577
# Epoch_metric: 0.5423
# test_loss_epoch: 0.4165
# test_dice_epoch: 0.5835
# current epoch: 2 current mean dice: 0.5182
# best mean dice: 0.5835 at epoch: 2
# ----------
# epoch 3/120
# 1/172, Train_loss: 0.4775
# Train_dice: 0.5225
# 2/172, Train_loss: 0.3773
# Train_dice: 0.6227
# 3/172, Train_loss: 0.3175
# Train_dice: 0.6825
# 4/172, Train_loss: 0.5089
# Train_dice: 0.4911
# 5/172, Train_loss: 0.3549
# Train_dice: 0.6451
# 6/172, Train_loss: 0.2911
# Train_dice: 0.7089
# 7/172, Train_loss: 0.4123
# Train_dice: 0.5877
# 8/172, Train_loss: 0.5435
# Train_dice: 0.4565
# 9/172, Train_loss: 0.4618
# Train_dice: 0.5382
# 10/172, Train_loss: 0.3916
# Train_dice: 0.6084
# 11/172, Train_loss: 0.4729
# Train_dice: 0.5271
# 12/172, Train_loss: 0.3656
# Train_dice: 0.6344
# 13/172, Train_loss: 0.5120
# Train_dice: 0.4880
# 14/172, Train_loss: 0.3576
# Train_dice: 0.6424
# 15/172, Train_loss: 0.3678
# Train_dice: 0.6322
# 16/172, Train_loss: 0.5322
# Train_dice: 0.4678
# 17/172, Train_loss: 0.3705
# Train_dice: 0.6295
# 18/172, Train_loss: 0.4603
# Train_dice: 0.5397
# 19/172, Train_loss: 0.3373
# Train_dice: 0.6627
# 20/172, Train_loss: 0.4520
# Train_dice: 0.5480
# 21/172, Train_loss: 0.5751
# Train_dice: 0.4249
# 22/172, Train_loss: 0.3167
# Train_dice: 0.6833
# 23/172, Train_loss: 0.3923
# Train_dice: 0.6077
# 24/172, Train_loss: 0.5571
# Train_dice: 0.4429
# 25/172, Train_loss: 0.5438
# Train_dice: 0.4562
# 26/172, Train_loss: 0.3720
# Train_dice: 0.6280
# 27/172, Train_loss: 0.4411
# Train_dice: 0.5589
# 28/172, Train_loss: 0.5744
# Train_dice: 0.4256
# 29/172, Train_loss: 0.5428
# Train_dice: 0.4572
# 30/172, Train_loss: 0.3137
# Train_dice: 0.6863
# 31/172, Train_loss: 0.4235
# Train_dice: 0.5765
# 32/172, Train_loss: 0.5793
# Train_dice: 0.4207
# 33/172, Train_loss: 0.5021
# Train_dice: 0.4979
# 34/172, Train_loss: 0.5195
# Train_dice: 0.4805
# 35/172, Train_loss: 0.3201
# Train_dice: 0.6799
# 36/172, Train_loss: 0.4258
# Train_dice: 0.5742
# 37/172, Train_loss: 0.3593
# Train_dice: 0.6407
# 38/172, Train_loss: 0.4068
# Train_dice: 0.5932
# 39/172, Train_loss: 0.5424
# Train_dice: 0.4576
# 40/172, Train_loss: 0.3893
# Train_dice: 0.6107
# 41/172, Train_loss: 0.4258
# Train_dice: 0.5742
# 42/172, Train_loss: 0.4064
# Train_dice: 0.5936
# 43/172, Train_loss: 0.4687
# Train_dice: 0.5313
# 44/172, Train_loss: 0.4403
# Train_dice: 0.5597
# 45/172, Train_loss: 0.5623
# Train_dice: 0.4377
# 46/172, Train_loss: 0.4936
# Train_dice: 0.5064
# 47/172, Train_loss: 0.3550
# Train_dice: 0.6450
# 48/172, Train_loss: 0.4647
# Train_dice: 0.5353
# 49/172, Train_loss: 0.5644
# Train_dice: 0.4356
# 50/172, Train_loss: 0.3489
# Train_dice: 0.6511
# 51/172, Train_loss: 0.3815
# Train_dice: 0.6185
# 52/172, Train_loss: 0.5217
# Train_dice: 0.4783
# 53/172, Train_loss: 0.3375
# Train_dice: 0.6625
# 54/172, Train_loss: 0.4101
# Train_dice: 0.5899
# 55/172, Train_loss: 0.5335
# Train_dice: 0.4665
# 56/172, Train_loss: 0.3258
# Train_dice: 0.6742
# 57/172, Train_loss: 0.4342
# Train_dice: 0.5658
# 58/172, Train_loss: 0.3887
# Train_dice: 0.6113
# 59/172, Train_loss: 0.4843
# Train_dice: 0.5157
# 60/172, Train_loss: 0.3462
# Train_dice: 0.6538
# 61/172, Train_loss: 0.5543
# Train_dice: 0.4457
# 62/172, Train_loss: 0.3592
# Train_dice: 0.6408
# 63/172, Train_loss: 0.3664
# Train_dice: 0.6336
# 64/172, Train_loss: 0.4684
# Train_dice: 0.5316
# 65/172, Train_loss: 0.5463
# Train_dice: 0.4537
# 66/172, Train_loss: 0.3513
# Train_dice: 0.6487
# 67/172, Train_loss: 0.5322
# Train_dice: 0.4678
# 68/172, Train_loss: 0.5110
# Train_dice: 0.4890
# 69/172, Train_loss: 0.3463
# Train_dice: 0.6537
# 70/172, Train_loss: 0.3894
# Train_dice: 0.6106
# 71/172, Train_loss: 0.3498
# Train_dice: 0.6502
# 72/172, Train_loss: 0.4435
# Train_dice: 0.5565
# 73/172, Train_loss: 0.4652
# Train_dice: 0.5348
# 74/172, Train_loss: 0.5133
# Train_dice: 0.4867
# 75/172, Train_loss: 0.5708
# Train_dice: 0.4292
# 76/172, Train_loss: 0.3382
# Train_dice: 0.6618
# 77/172, Train_loss: 0.3977
# Train_dice: 0.6023
# 78/172, Train_loss: 0.4781
# Train_dice: 0.5219
# 79/172, Train_loss: 0.3838
# Train_dice: 0.6162
# 80/172, Train_loss: 0.5321
# Train_dice: 0.4679
# 81/172, Train_loss: 0.3326
# Train_dice: 0.6674
# 82/172, Train_loss: 0.3038
# Train_dice: 0.6962
# 83/172, Train_loss: 0.4339
# Train_dice: 0.5661
# 84/172, Train_loss: 0.5742
# Train_dice: 0.4258
# 85/172, Train_loss: 0.5569
# Train_dice: 0.4431
# 86/172, Train_loss: 0.5551
# Train_dice: 0.4449
# 87/172, Train_loss: 0.5699
# Train_dice: 0.4301
# 88/172, Train_loss: 0.5547
# Train_dice: 0.4453
# 89/172, Train_loss: 0.5576
# Train_dice: 0.4424
# 90/172, Train_loss: 0.3632
# Train_dice: 0.6368
# 91/172, Train_loss: 0.4386
# Train_dice: 0.5614
# 92/172, Train_loss: 0.5188
# Train_dice: 0.4812
# 93/172, Train_loss: 0.4010
# Train_dice: 0.5990
# 94/172, Train_loss: 0.5767
# Train_dice: 0.4233
# 95/172, Train_loss: 0.4654
# Train_dice: 0.5346
# 96/172, Train_loss: 0.3968
# Train_dice: 0.6032
# 97/172, Train_loss: 0.5281
# Train_dice: 0.4719
# 98/172, Train_loss: 0.5696
# Train_dice: 0.4304
# 99/172, Train_loss: 0.4525
# Train_dice: 0.5475
# 100/172, Train_loss: 0.3204
# Train_dice: 0.6796
# 101/172, Train_loss: 0.4975
# Train_dice: 0.5025
# 102/172, Train_loss: 0.4759
# Train_dice: 0.5241
# 103/172, Train_loss: 0.4566
# Train_dice: 0.5434
# 104/172, Train_loss: 0.4653
# Train_dice: 0.5347
# 105/172, Train_loss: 0.4664
# Train_dice: 0.5336
# 106/172, Train_loss: 0.4639
# Train_dice: 0.5361
# 107/172, Train_loss: 0.3554
# Train_dice: 0.6446
# 108/172, Train_loss: 0.5816
# Train_dice: 0.4184
# 109/172, Train_loss: 0.4610
# Train_dice: 0.5390
# 110/172, Train_loss: 0.5606
# Train_dice: 0.4394
# 111/172, Train_loss: 0.4832
# Train_dice: 0.5168
# 112/172, Train_loss: 0.3659
# Train_dice: 0.6341
# 113/172, Train_loss: 0.4585
# Train_dice: 0.5415
# 114/172, Train_loss: 0.3694
# Train_dice: 0.6306
# 115/172, Train_loss: 0.4437
# Train_dice: 0.5563
# 116/172, Train_loss: 0.3434
# Train_dice: 0.6566
# 117/172, Train_loss: 0.3956
# Train_dice: 0.6044
# 118/172, Train_loss: 0.2641
# Train_dice: 0.7359
# 119/172, Train_loss: 0.3814
# Train_dice: 0.6186
# 120/172, Train_loss: 0.3686
# Train_dice: 0.6314
# 121/172, Train_loss: 0.3697
# Train_dice: 0.6303
# 122/172, Train_loss: 0.5357
# Train_dice: 0.4643
# 123/172, Train_loss: 0.4023
# Train_dice: 0.5977
# 124/172, Train_loss: 0.3006
# Train_dice: 0.6994
# 125/172, Train_loss: 0.4048
# Train_dice: 0.5952
# 126/172, Train_loss: 0.5352
# Train_dice: 0.4648
# 127/172, Train_loss: 0.3797
# Train_dice: 0.6203
# 128/172, Train_loss: 0.3013
# Train_dice: 0.6987
# 129/172, Train_loss: 0.4306
# Train_dice: 0.5694
# 130/172, Train_loss: 0.3388
# Train_dice: 0.6612
# 131/172, Train_loss: 0.5321
# Train_dice: 0.4679
# 132/172, Train_loss: 0.4731
# Train_dice: 0.5269
# 133/172, Train_loss: 0.3500
# Train_dice: 0.6500
# 134/172, Train_loss: 0.4853
# Train_dice: 0.5147
# 135/172, Train_loss: 0.3202
# Train_dice: 0.6798
# 136/172, Train_loss: 0.4857
# Train_dice: 0.5143
# 137/172, Train_loss: 0.4831
# Train_dice: 0.5169
# 138/172, Train_loss: 0.3452
# Train_dice: 0.6548
# 139/172, Train_loss: 0.4712
# Train_dice: 0.5288
# 140/172, Train_loss: 0.4295
# Train_dice: 0.5705
# 141/172, Train_loss: 0.5007
# Train_dice: 0.4993
# 142/172, Train_loss: 0.5419
# Train_dice: 0.4581
# 143/172, Train_loss: 0.3508
# Train_dice: 0.6492
# 144/172, Train_loss: 0.4087
# Train_dice: 0.5913
# 145/172, Train_loss: 0.3104
# Train_dice: 0.6896
# 146/172, Train_loss: 0.5637
# Train_dice: 0.4363
# 147/172, Train_loss: 0.3480
# Train_dice: 0.6520
# 148/172, Train_loss: 0.3056
# Train_dice: 0.6944
# 149/172, Train_loss: 0.4905
# Train_dice: 0.5095
# 150/172, Train_loss: 0.5665
# Train_dice: 0.4335
# 151/172, Train_loss: 0.4764
# Train_dice: 0.5236
# 152/172, Train_loss: 0.3611
# Train_dice: 0.6389
# 153/172, Train_loss: 0.4285
# Train_dice: 0.5715
# 154/172, Train_loss: 0.5700
# Train_dice: 0.4300
# 155/172, Train_loss: 0.4895
# Train_dice: 0.5105
# 156/172, Train_loss: 0.3310
# Train_dice: 0.6690
# 157/172, Train_loss: 0.4655
# Train_dice: 0.5345
# 158/172, Train_loss: 0.5682
# Train_dice: 0.4318
# 159/172, Train_loss: 0.4804
# Train_dice: 0.5196
# 160/172, Train_loss: 0.3948
# Train_dice: 0.6052
# 161/172, Train_loss: 0.2956
# Train_dice: 0.7044
# 162/172, Train_loss: 0.3459
# Train_dice: 0.6541
# 163/172, Train_loss: 0.5526
# Train_dice: 0.4474
# 164/172, Train_loss: 0.3913
# Train_dice: 0.6087
# 165/172, Train_loss: 0.2904
# Train_dice: 0.7096
# 166/172, Train_loss: 0.3932
# Train_dice: 0.6068
# 167/172, Train_loss: 0.4014
# Train_dice: 0.5986
# 168/172, Train_loss: 0.2937
# Train_dice: 0.7063
# 169/172, Train_loss: 0.4746
# Train_dice: 0.5254
# 170/172, Train_loss: 0.3122
# Train_dice: 0.6878
# 171/172, Train_loss: 0.4854
# Train_dice: 0.5146
# 172/172, Train_loss: 0.3779
# Train_dice: 0.6221
# --------------------
# Epoch_loss: 0.4368
# Epoch_metric: 0.5632
# test_loss_epoch: 0.3990
# test_dice_epoch: 0.6010
# current epoch: 3 current mean dice: 0.5342
# best mean dice: 0.6010 at epoch: 3
# ----------
# epoch 4/120
# 1/172, Train_loss: 0.4627
# Train_dice: 0.5373
# 2/172, Train_loss: 0.3557
# Train_dice: 0.6443
# 3/172, Train_loss: 0.2934
# Train_dice: 0.7066
# 4/172, Train_loss: 0.4952
# Train_dice: 0.5048
# 5/172, Train_loss: 0.3324
# Train_dice: 0.6676
# 6/172, Train_loss: 0.2671
# Train_dice: 0.7329
# 7/172, Train_loss: 0.3925
# Train_dice: 0.6075
# 8/172, Train_loss: 0.5323
# Train_dice: 0.4677
# 9/172, Train_loss: 0.4463
# Train_dice: 0.5537
# 10/172, Train_loss: 0.3722
# Train_dice: 0.6278
# 11/172, Train_loss: 0.4580
# Train_dice: 0.5420
# 12/172, Train_loss: 0.3433
# Train_dice: 0.6567
# 13/172, Train_loss: 0.4994
# Train_dice: 0.5006
# 14/172, Train_loss: 0.3361
# Train_dice: 0.6639
# 15/172, Train_loss: 0.3462
# Train_dice: 0.6538
# 16/172, Train_loss: 0.5219
# Train_dice: 0.4781
# 17/172, Train_loss: 0.3509
# Train_dice: 0.6491
# 18/172, Train_loss: 0.4435
# Train_dice: 0.5565
# 19/172, Train_loss: 0.3145
# Train_dice: 0.6855
# 20/172, Train_loss: 0.4317
# Train_dice: 0.5683
# 21/172, Train_loss: 0.5693
# Train_dice: 0.4307
# 22/172, Train_loss: 0.2924
# Train_dice: 0.7076
# 23/172, Train_loss: 0.3724
# Train_dice: 0.6276
# 24/172, Train_loss: 0.5495
# Train_dice: 0.4505
# 25/172, Train_loss: 0.5337
# Train_dice: 0.4663
# 26/172, Train_loss: 0.3508
# Train_dice: 0.6492
# 27/172, Train_loss: 0.4250
# Train_dice: 0.5750
# 28/172, Train_loss: 0.5688
# Train_dice: 0.4312
# 29/172, Train_loss: 0.5339
# Train_dice: 0.4661
# 30/172, Train_loss: 0.2930
# Train_dice: 0.7070
# 31/172, Train_loss: 0.4056
# Train_dice: 0.5944
# 32/172, Train_loss: 0.5734
# Train_dice: 0.4266
# 33/172, Train_loss: 0.4906
# Train_dice: 0.5094
# 34/172, Train_loss: 0.5082
# Train_dice: 0.4918
# 35/172, Train_loss: 0.2995
# Train_dice: 0.7005
# 36/172, Train_loss: 0.4076
# Train_dice: 0.5924
# 37/172, Train_loss: 0.3399
# Train_dice: 0.6601
# 38/172, Train_loss: 0.3875
# Train_dice: 0.6125
# 39/172, Train_loss: 0.5338
# Train_dice: 0.4662
# 40/172, Train_loss: 0.3711
# Train_dice: 0.6289
# 41/172, Train_loss: 0.4089
# Train_dice: 0.5911
# 42/172, Train_loss: 0.3892
# Train_dice: 0.6108
# 43/172, Train_loss: 0.4543
# Train_dice: 0.5457
# 44/172, Train_loss: 0.4245
# Train_dice: 0.5755
# 45/172, Train_loss: 0.5556
# Train_dice: 0.4444
# 46/172, Train_loss: 0.4814
# Train_dice: 0.5186
# 47/172, Train_loss: 0.3358
# Train_dice: 0.6642
# 48/172, Train_loss: 0.4513
# Train_dice: 0.5487
# 49/172, Train_loss: 0.5577
# Train_dice: 0.4423
# 50/172, Train_loss: 0.3304
# Train_dice: 0.6696
# 51/172, Train_loss: 0.3635
# Train_dice: 0.6365
# 52/172, Train_loss: 0.5038
# Train_dice: 0.4962
# 53/172, Train_loss: 0.3107
# Train_dice: 0.6893
# 54/172, Train_loss: 0.3866
# Train_dice: 0.6134
# 55/172, Train_loss: 0.5243
# Train_dice: 0.4757
# 56/172, Train_loss: 0.3076
# Train_dice: 0.6924
# 57/172, Train_loss: 0.4194
# Train_dice: 0.5806
# 58/172, Train_loss: 0.3740
# Train_dice: 0.6260
# 59/172, Train_loss: 0.4685
# Train_dice: 0.5315
# 60/172, Train_loss: 0.3261
# Train_dice: 0.6739
# 61/172, Train_loss: 0.5452
# Train_dice: 0.4548
# 62/172, Train_loss: 0.3398
# Train_dice: 0.6602
# 63/172, Train_loss: 0.3478
# Train_dice: 0.6522
# 64/172, Train_loss: 0.4517
# Train_dice: 0.5483
# 65/172, Train_loss: 0.5374
# Train_dice: 0.4626
# 66/172, Train_loss: 0.3317
# Train_dice: 0.6683
# 67/172, Train_loss: 0.5228
# Train_dice: 0.4772
# 68/172, Train_loss: 0.4997
# Train_dice: 0.5003
# 69/172, Train_loss: 0.3257
# Train_dice: 0.6743
# 70/172, Train_loss: 0.3744
# Train_dice: 0.6256
# 71/172, Train_loss: 0.3301
# Train_dice: 0.6699
# 72/172, Train_loss: 0.4265
# Train_dice: 0.5735
# 73/172, Train_loss: 0.4476
# Train_dice: 0.5524
# 74/172, Train_loss: 0.5005
# Train_dice: 0.4995
# 75/172, Train_loss: 0.5622
# Train_dice: 0.4378
# 76/172, Train_loss: 0.3176
# Train_dice: 0.6824
# 77/172, Train_loss: 0.3795
# Train_dice: 0.6205
# 78/172, Train_loss: 0.4635
# Train_dice: 0.5365
# 79/172, Train_loss: 0.3666
# Train_dice: 0.6334
# 80/172, Train_loss: 0.5240
# Train_dice: 0.4760
# 81/172, Train_loss: 0.3134
# Train_dice: 0.6866
# 82/172, Train_loss: 0.2834
# Train_dice: 0.7166
# 83/172, Train_loss: 0.4150
# Train_dice: 0.5850
# 84/172, Train_loss: 0.5670
# Train_dice: 0.4330
# 85/172, Train_loss: 0.5532
# Train_dice: 0.4468
# 86/172, Train_loss: 0.5481
# Train_dice: 0.4519
# 87/172, Train_loss: 0.5669
# Train_dice: 0.4331
# 88/172, Train_loss: 0.5472
# Train_dice: 0.4528
# 89/172, Train_loss: 0.5486
# Train_dice: 0.4514
# 90/172, Train_loss: 0.3431
# Train_dice: 0.6569
# 91/172, Train_loss: 0.4230
# Train_dice: 0.5770
# 92/172, Train_loss: 0.5051
# Train_dice: 0.4949
# 93/172, Train_loss: 0.3834
# Train_dice: 0.6166
# 94/172, Train_loss: 0.5713
# Train_dice: 0.4287
# 95/172, Train_loss: 0.4533
# Train_dice: 0.5467
# 96/172, Train_loss: 0.3791
# Train_dice: 0.6209
# 97/172, Train_loss: 0.5192
# Train_dice: 0.4808
# 98/172, Train_loss: 0.5624
# Train_dice: 0.4376
# 99/172, Train_loss: 0.4320
# Train_dice: 0.5680
# 100/172, Train_loss: 0.3010
# Train_dice: 0.6990
# 101/172, Train_loss: 0.4850
# Train_dice: 0.5150
# 102/172, Train_loss: 0.4621
# Train_dice: 0.5379
# 103/172, Train_loss: 0.4449
# Train_dice: 0.5551
# 104/172, Train_loss: 0.4528
# Train_dice: 0.5472
# 105/172, Train_loss: 0.4540
# Train_dice: 0.5460
# 106/172, Train_loss: 0.4503
# Train_dice: 0.5497
# 107/172, Train_loss: 0.3347
# Train_dice: 0.6653
# 108/172, Train_loss: 0.5759
# Train_dice: 0.4241
# 109/172, Train_loss: 0.4468
# Train_dice: 0.5532
# 110/172, Train_loss: 0.5532
# Train_dice: 0.4468
# 111/172, Train_loss: 0.4714
# Train_dice: 0.5286
# 112/172, Train_loss: 0.3472
# Train_dice: 0.6528
# 113/172, Train_loss: 0.4453
# Train_dice: 0.5547
# 114/172, Train_loss: 0.3530
# Train_dice: 0.6470
# 115/172, Train_loss: 0.4287
# Train_dice: 0.5713
# 116/172, Train_loss: 0.3245
# Train_dice: 0.6755
# 117/172, Train_loss: 0.3793
# Train_dice: 0.6207
# 118/172, Train_loss: 0.2450
# Train_dice: 0.7550
# 119/172, Train_loss: 0.3629
# Train_dice: 0.6371
# 120/172, Train_loss: 0.3526
# Train_dice: 0.6474
# 121/172, Train_loss: 0.3548
# Train_dice: 0.6452
# 122/172, Train_loss: 0.5272
# Train_dice: 0.4728
# 123/172, Train_loss: 0.3857
# Train_dice: 0.6143
# 124/172, Train_loss: 0.2806
# Train_dice: 0.7194
# 125/172, Train_loss: 0.3874
# Train_dice: 0.6126
# 126/172, Train_loss: 0.5270
# Train_dice: 0.4730
# 127/172, Train_loss: 0.3620
# Train_dice: 0.6380
# 128/172, Train_loss: 0.2828
# Train_dice: 0.7172
# 129/172, Train_loss: 0.4153
# Train_dice: 0.5847
# 130/172, Train_loss: 0.3204
# Train_dice: 0.6796
# 131/172, Train_loss: 0.5237
# Train_dice: 0.4763
# 132/172, Train_loss: 0.4614
# Train_dice: 0.5386
# 133/172, Train_loss: 0.3326
# Train_dice: 0.6674
# 134/172, Train_loss: 0.4739
# Train_dice: 0.5261
# 135/172, Train_loss: 0.3024
# Train_dice: 0.6976
# 136/172, Train_loss: 0.4733
# Train_dice: 0.5267
# 137/172, Train_loss: 0.4709
# Train_dice: 0.5291
# 138/172, Train_loss: 0.3267
# Train_dice: 0.6733
# 139/172, Train_loss: 0.4579
# Train_dice: 0.5421
# 140/172, Train_loss: 0.4146
# Train_dice: 0.5854
# 141/172, Train_loss: 0.4888
# Train_dice: 0.5112
# 142/172, Train_loss: 0.5347
# Train_dice: 0.4653
# 143/172, Train_loss: 0.3322
# Train_dice: 0.6678
# 144/172, Train_loss: 0.3933
# Train_dice: 0.6067
# 145/172, Train_loss: 0.2926
# Train_dice: 0.7074
# 146/172, Train_loss: 0.5576
# Train_dice: 0.4424
# 147/172, Train_loss: 0.3284
# Train_dice: 0.6716
# 148/172, Train_loss: 0.2885
# Train_dice: 0.7115
# 149/172, Train_loss: 0.4775
# Train_dice: 0.5225
# 150/172, Train_loss: 0.5609
# Train_dice: 0.4391
# 151/172, Train_loss: 0.4647
# Train_dice: 0.5353
# 152/172, Train_loss: 0.3435
# Train_dice: 0.6565
# 153/172, Train_loss: 0.4139
# Train_dice: 0.5861
# 154/172, Train_loss: 0.5647
# Train_dice: 0.4353
# 155/172, Train_loss: 0.4785
# Train_dice: 0.5215
# 156/172, Train_loss: 0.3127
# Train_dice: 0.6873
# 157/172, Train_loss: 0.4522
# Train_dice: 0.5478
# 158/172, Train_loss: 0.5629
# Train_dice: 0.4371
# 159/172, Train_loss: 0.4686
# Train_dice: 0.5314
# 160/172, Train_loss: 0.3781
# Train_dice: 0.6219
# 161/172, Train_loss: 0.2767
# Train_dice: 0.7233
# 162/172, Train_loss: 0.3286
# Train_dice: 0.6714
# 163/172, Train_loss: 0.5463
# Train_dice: 0.4537
# 164/172, Train_loss: 0.3747
# Train_dice: 0.6253
# 165/172, Train_loss: 0.2723
# Train_dice: 0.7277
# 166/172, Train_loss: 0.3778
# Train_dice: 0.6222
# 167/172, Train_loss: 0.3861
# Train_dice: 0.6139
# 168/172, Train_loss: 0.2766
# Train_dice: 0.7234
# 169/172, Train_loss: 0.4631
# Train_dice: 0.5369
# 170/172, Train_loss: 0.2950
# Train_dice: 0.7050
# 171/172, Train_loss: 0.4747
# Train_dice: 0.5253
# 172/172, Train_loss: 0.3608
# Train_dice: 0.6392
# --------------------
# Epoch_loss: 0.4219
# Epoch_metric: 0.5781
# test_loss_epoch: 0.3872
# test_dice_epoch: 0.6128
# current epoch: 4 current mean dice: 0.5486
# best mean dice: 0.6128 at epoch: 4
# ----------
# epoch 5/120
# 1/172, Train_loss: 0.4495
# Train_dice: 0.5505
# 2/172, Train_loss: 0.3393
# Train_dice: 0.6607
# 3/172, Train_loss: 0.2750
# Train_dice: 0.7250
# 4/172, Train_loss: 0.4843
# Train_dice: 0.5157
# 5/172, Train_loss: 0.3150
# Train_dice: 0.6850
# 6/172, Train_loss: 0.2483
# Train_dice: 0.7517
# 7/172, Train_loss: 0.3767
# Train_dice: 0.6233
# 8/172, Train_loss: 0.5234
# Train_dice: 0.4766
# 9/172, Train_loss: 0.4337
# Train_dice: 0.5663
# 10/172, Train_loss: 0.3563
# Train_dice: 0.6437
# 11/172, Train_loss: 0.4455
# Train_dice: 0.5545
# 12/172, Train_loss: 0.3250
# Train_dice: 0.6750
# 13/172, Train_loss: 0.4893
# Train_dice: 0.5107
# 14/172, Train_loss: 0.3188
# Train_dice: 0.6812
# 15/172, Train_loss: 0.3288
# Train_dice: 0.6712
# 16/172, Train_loss: 0.5137
# Train_dice: 0.4863
# 17/172, Train_loss: 0.3336
# Train_dice: 0.6664
# 18/172, Train_loss: 0.4283
# Train_dice: 0.5717
# 19/172, Train_loss: 0.2958
# Train_dice: 0.7042
# 20/172, Train_loss: 0.4148
# Train_dice: 0.5852
# 21/172, Train_loss: 0.5645
# Train_dice: 0.4355
# 22/172, Train_loss: 0.2738
# Train_dice: 0.7262
# 23/172, Train_loss: 0.3565
# Train_dice: 0.6435
# 24/172, Train_loss: 0.5433
# Train_dice: 0.4567
# 25/172, Train_loss: 0.5271
# Train_dice: 0.4729
# 26/172, Train_loss: 0.3341
# Train_dice: 0.6659
# 27/172, Train_loss: 0.4110
# Train_dice: 0.5890
# 28/172, Train_loss: 0.5640
# Train_dice: 0.4360
# 29/172, Train_loss: 0.5269
# Train_dice: 0.4731
# 30/172, Train_loss: 0.2753
# Train_dice: 0.7247
# 31/172, Train_loss: 0.3901
# Train_dice: 0.6099
# 32/172, Train_loss: 0.5689
# Train_dice: 0.4311
# 33/172, Train_loss: 0.4808
# Train_dice: 0.5192
# 34/172, Train_loss: 0.4996
# Train_dice: 0.5004
# 35/172, Train_loss: 0.2827
# Train_dice: 0.7173
# 36/172, Train_loss: 0.3926
# Train_dice: 0.6074
# 37/172, Train_loss: 0.3239
# Train_dice: 0.6761
# 38/172, Train_loss: 0.3717
# Train_dice: 0.6283
# 39/172, Train_loss: 0.5266
# Train_dice: 0.4734
# 40/172, Train_loss: 0.3552
# Train_dice: 0.6448
# 41/172, Train_loss: 0.3935
# Train_dice: 0.6065
# 42/172, Train_loss: 0.3747
# Train_dice: 0.6253
# 43/172, Train_loss: 0.4420
# Train_dice: 0.5580
# 44/172, Train_loss: 0.4113
# Train_dice: 0.5887
# 45/172, Train_loss: 0.5501
# Train_dice: 0.4499
# 46/172, Train_loss: 0.4719
# Train_dice: 0.5281
# 47/172, Train_loss: 0.3201
# Train_dice: 0.6799
# 48/172, Train_loss: 0.4400
# Train_dice: 0.5600
# 49/172, Train_loss: 0.5528
# Train_dice: 0.4472
# 50/172, Train_loss: 0.3145
# Train_dice: 0.6855
# 51/172, Train_loss: 0.3479
# Train_dice: 0.6521
# 52/172, Train_loss: 0.4916
# Train_dice: 0.5084
# 53/172, Train_loss: 0.2914
# Train_dice: 0.7086
# 54/172, Train_loss: 0.3680
# Train_dice: 0.6320
# 55/172, Train_loss: 0.5171
# Train_dice: 0.4829
# 56/172, Train_loss: 0.2915
# Train_dice: 0.7085
# 57/172, Train_loss: 0.4049
# Train_dice: 0.5951
# 58/172, Train_loss: 0.3580
# Train_dice: 0.6420
# 59/172, Train_loss: 0.4572
# Train_dice: 0.5428
# 60/172, Train_loss: 0.3099
# Train_dice: 0.6901
# 61/172, Train_loss: 0.5358
# Train_dice: 0.4642
# 62/172, Train_loss: 0.3231
# Train_dice: 0.6769
# 63/172, Train_loss: 0.3322
# Train_dice: 0.6678
# 64/172, Train_loss: 0.4389
# Train_dice: 0.5611
# 65/172, Train_loss: 0.5271
# Train_dice: 0.4729
# 66/172, Train_loss: 0.3155
# Train_dice: 0.6845
# 67/172, Train_loss: 0.5142
# Train_dice: 0.4858
# 68/172, Train_loss: 0.4891
# Train_dice: 0.5109
# 69/172, Train_loss: 0.3081
# Train_dice: 0.6919
# 70/172, Train_loss: 0.3597
# Train_dice: 0.6403
# 71/172, Train_loss: 0.3137
# Train_dice: 0.6863
# 72/172, Train_loss: 0.4129
# Train_dice: 0.5871
# 73/172, Train_loss: 0.4333
# Train_dice: 0.5667
# 74/172, Train_loss: 0.4901
# Train_dice: 0.5099
# 75/172, Train_loss: 0.5536
# Train_dice: 0.4464
# 76/172, Train_loss: 0.2993
# Train_dice: 0.7007
# 77/172, Train_loss: 0.3654
# Train_dice: 0.6346
# 78/172, Train_loss: 0.4522
# Train_dice: 0.5478
# 79/172, Train_loss: 0.3519
# Train_dice: 0.6481
# 80/172, Train_loss: 0.5146
# Train_dice: 0.4854
# 81/172, Train_loss: 0.2934
# Train_dice: 0.7066
# 82/172, Train_loss: 0.2662
# Train_dice: 0.7338
# 83/172, Train_loss: 0.4002
# Train_dice: 0.5998
# 84/172, Train_loss: 0.5616
# Train_dice: 0.4384
# 85/172, Train_loss: 0.5503
# Train_dice: 0.4497
# 86/172, Train_loss: 0.5405
# Train_dice: 0.4595
# 87/172, Train_loss: 0.5643
# Train_dice: 0.4357
# 88/172, Train_loss: 0.5405
# Train_dice: 0.4595
# 89/172, Train_loss: 0.5419
# Train_dice: 0.4581
# 90/172, Train_loss: 0.3252
# Train_dice: 0.6748
# 91/172, Train_loss: 0.4100
# Train_dice: 0.5900
# 92/172, Train_loss: 0.4962
# Train_dice: 0.5038
# 93/172, Train_loss: 0.3685
# Train_dice: 0.6315
# 94/172, Train_loss: 0.5671
# Train_dice: 0.4329
# 95/172, Train_loss: 0.4426
# Train_dice: 0.5574
# 96/172, Train_loss: 0.3638
# Train_dice: 0.6362
# 97/172, Train_loss: 0.5115
# Train_dice: 0.4885
# 98/172, Train_loss: 0.5570
# Train_dice: 0.4430
# 99/172, Train_loss: 0.4151
# Train_dice: 0.5849
# 100/172, Train_loss: 0.2835
# Train_dice: 0.7165
# 101/172, Train_loss: 0.4761
# Train_dice: 0.5239
# 102/172, Train_loss: 0.4506
# Train_dice: 0.5494
# 103/172, Train_loss: 0.4349
# Train_dice: 0.5651
# 104/172, Train_loss: 0.4416
# Train_dice: 0.5584
# 105/172, Train_loss: 0.4432
# Train_dice: 0.5568
# 106/172, Train_loss: 0.4384
# Train_dice: 0.5616
# 107/172, Train_loss: 0.3163
# Train_dice: 0.6837
# 108/172, Train_loss: 0.5706
# Train_dice: 0.4294
# 109/172, Train_loss: 0.4349
# Train_dice: 0.5651
# 110/172, Train_loss: 0.5466
# Train_dice: 0.4534
# 111/172, Train_loss: 0.4617
# Train_dice: 0.5383
# 112/172, Train_loss: 0.3313
# Train_dice: 0.6687
# 113/172, Train_loss: 0.4334
# Train_dice: 0.5666
# 114/172, Train_loss: 0.3389
# Train_dice: 0.6611
# 115/172, Train_loss: 0.4165
# Train_dice: 0.5835
# 116/172, Train_loss: 0.3082
# Train_dice: 0.6918
# 117/172, Train_loss: 0.3643
# Train_dice: 0.6357
# 118/172, Train_loss: 0.2281
# Train_dice: 0.7719
# 119/172, Train_loss: 0.3462
# Train_dice: 0.6538
# 120/172, Train_loss: 0.3380
# Train_dice: 0.6620
# 121/172, Train_loss: 0.3421
# Train_dice: 0.6579
# 122/172, Train_loss: 0.5202
# Train_dice: 0.4798
# 123/172, Train_loss: 0.3713
# Train_dice: 0.6287
# 124/172, Train_loss: 0.2631
# Train_dice: 0.7369
# 125/172, Train_loss: 0.3729
# Train_dice: 0.6271
# 126/172, Train_loss: 0.5199
# Train_dice: 0.4801
# 127/172, Train_loss: 0.3463
# Train_dice: 0.6537
# 128/172, Train_loss: 0.2663
# Train_dice: 0.7337
# 129/172, Train_loss: 0.4023
# Train_dice: 0.5977
# 130/172, Train_loss: 0.3047
# Train_dice: 0.6953
# 131/172, Train_loss: 0.5171
# Train_dice: 0.4829
# 132/172, Train_loss: 0.4514
# Train_dice: 0.5486
# 133/172, Train_loss: 0.3166
# Train_dice: 0.6834
# 134/172, Train_loss: 0.4641
# Train_dice: 0.5359
# 135/172, Train_loss: 0.2866
# Train_dice: 0.7134
# 136/172, Train_loss: 0.4623
# Train_dice: 0.5377
# 137/172, Train_loss: 0.4613
# Train_dice: 0.5387
# 138/172, Train_loss: 0.3106
# Train_dice: 0.6894
# 139/172, Train_loss: 0.4466
# Train_dice: 0.5534
# 140/172, Train_loss: 0.4018
# Train_dice: 0.5982
# 141/172, Train_loss: 0.4792
# Train_dice: 0.5208
# 142/172, Train_loss: 0.5288
# Train_dice: 0.4712
# 143/172, Train_loss: 0.3164
# Train_dice: 0.6836
# 144/172, Train_loss: 0.3801
# Train_dice: 0.6199
# 145/172, Train_loss: 0.2768
# Train_dice: 0.7232
# 146/172, Train_loss: 0.5527
# Train_dice: 0.4473
# 147/172, Train_loss: 0.3113
# Train_dice: 0.6887
# 148/172, Train_loss: 0.2731
# Train_dice: 0.7269
# 149/172, Train_loss: 0.4671
# Train_dice: 0.5329
# 150/172, Train_loss: 0.5567
# Train_dice: 0.4433
# 151/172, Train_loss: 0.4555
# Train_dice: 0.5445
# 152/172, Train_loss: 0.3289
# Train_dice: 0.6711
# 153/172, Train_loss: 0.4021
# Train_dice: 0.5979
# 154/172, Train_loss: 0.5605
# Train_dice: 0.4395
# 155/172, Train_loss: 0.4696
# Train_dice: 0.5304
# 156/172, Train_loss: 0.2966
# Train_dice: 0.7034
# 157/172, Train_loss: 0.4407
# Train_dice: 0.5593
# 158/172, Train_loss: 0.5587
# Train_dice: 0.4413
# 159/172, Train_loss: 0.4591
# Train_dice: 0.5409
# 160/172, Train_loss: 0.3640
# Train_dice: 0.6360
# 161/172, Train_loss: 0.2599
# Train_dice: 0.7401
# 162/172, Train_loss: 0.3140
# Train_dice: 0.6860
# 163/172, Train_loss: 0.5411
# Train_dice: 0.4589
# 164/172, Train_loss: 0.3610
# Train_dice: 0.6390
# 165/172, Train_loss: 0.2567
# Train_dice: 0.7433
# 166/172, Train_loss: 0.3639
# Train_dice: 0.6361
# 167/172, Train_loss: 0.3731
# Train_dice: 0.6269
# 168/172, Train_loss: 0.2619
# Train_dice: 0.7381
# 169/172, Train_loss: 0.4534
# Train_dice: 0.5466
# 170/172, Train_loss: 0.2802
# Train_dice: 0.7198
# 171/172, Train_loss: 0.4660
# Train_dice: 0.5340
# 172/172, Train_loss: 0.3466
# Train_dice: 0.6534
# --------------------
# Epoch_loss: 0.4093
# Epoch_metric: 0.5907
# test_loss_epoch: 0.3779
# test_dice_epoch: 0.6221
# current epoch: 5 current mean dice: 0.5597
# best mean dice: 0.6221 at epoch: 5
# ----------
# epoch 6/120
# 1/172, Train_loss: 0.4387
# Train_dice: 0.5613
# 2/172, Train_loss: 0.3257
# Train_dice: 0.6743
# 3/172, Train_loss: 0.2593
# Train_dice: 0.7407
# 4/172, Train_loss: 0.4757
# Train_dice: 0.5243
# 5/172, Train_loss: 0.2996
# Train_dice: 0.7004
# 6/172, Train_loss: 0.2321
# Train_dice: 0.7679
# 7/172, Train_loss: 0.3635
# Train_dice: 0.6365
# 8/172, Train_loss: 0.5166
# Train_dice: 0.4834
# 9/172, Train_loss: 0.4234
# Train_dice: 0.5766
# 10/172, Train_loss: 0.3434
# Train_dice: 0.6566
# 11/172, Train_loss: 0.4355
# Train_dice: 0.5645
# 12/172, Train_loss: 0.3106
# Train_dice: 0.6894
# 13/172, Train_loss: 0.4813
# Train_dice: 0.5187
# 14/172, Train_loss: 0.3044
# Train_dice: 0.6956
# 15/172, Train_loss: 0.3145
# Train_dice: 0.6855
# 16/172, Train_loss: 0.5072
# Train_dice: 0.4928
# 17/172, Train_loss: 0.3193
# Train_dice: 0.6807
# 18/172, Train_loss: 0.4155
# Train_dice: 0.5845
# 19/172, Train_loss: 0.2801
# Train_dice: 0.7199
# 20/172, Train_loss: 0.3994
# Train_dice: 0.6006
# 21/172, Train_loss: 0.5604
# Train_dice: 0.4396
# 22/172, Train_loss: 0.2586
# Train_dice: 0.7414
# 23/172, Train_loss: 0.3434
# Train_dice: 0.6566
# 24/172, Train_loss: 0.5380
# Train_dice: 0.4620
# 25/172, Train_loss: 0.5218
# Train_dice: 0.4782
# 26/172, Train_loss: 0.3205
# Train_dice: 0.6795
# 27/172, Train_loss: 0.3998
# Train_dice: 0.6002
# 28/172, Train_loss: 0.5599
# Train_dice: 0.4401
# 29/172, Train_loss: 0.5214
# Train_dice: 0.4786
# 30/172, Train_loss: 0.2609
# Train_dice: 0.7391
# 31/172, Train_loss: 0.3780
# Train_dice: 0.6220
# 32/172, Train_loss: 0.5649
# Train_dice: 0.4351
# 33/172, Train_loss: 0.4728
# Train_dice: 0.5272
# 34/172, Train_loss: 0.4927
# Train_dice: 0.5073
# 35/172, Train_loss: 0.2685
# Train_dice: 0.7315
# 36/172, Train_loss: 0.3805
# Train_dice: 0.6195
# 37/172, Train_loss: 0.3104
# Train_dice: 0.6896
# 38/172, Train_loss: 0.3589
# Train_dice: 0.6411
# 39/172, Train_loss: 0.5204
# Train_dice: 0.4796
# 40/172, Train_loss: 0.3416
# Train_dice: 0.6584
# 41/172, Train_loss: 0.3807
# Train_dice: 0.6193
# 42/172, Train_loss: 0.3630
# Train_dice: 0.6370
# 43/172, Train_loss: 0.4323
# Train_dice: 0.5677
# 44/172, Train_loss: 0.4006
# Train_dice: 0.5994
# 45/172, Train_loss: 0.5457
# Train_dice: 0.4543
# 46/172, Train_loss: 0.4644
# Train_dice: 0.5356
# 47/172, Train_loss: 0.3074
# Train_dice: 0.6926
# 48/172, Train_loss: 0.4309
# Train_dice: 0.5691
# 49/172, Train_loss: 0.5487
# Train_dice: 0.4513
# 50/172, Train_loss: 0.3013
# Train_dice: 0.6987
# 51/172, Train_loss: 0.3352
# Train_dice: 0.6648
# 52/172, Train_loss: 0.4825
# Train_dice: 0.5175
# 53/172, Train_loss: 0.2749
# Train_dice: 0.7251
# 54/172, Train_loss: 0.3537
# Train_dice: 0.6463
# 55/172, Train_loss: 0.5112
# Train_dice: 0.4888
# 56/172, Train_loss: 0.2780
# Train_dice: 0.7220
# 57/172, Train_loss: 0.3922
# Train_dice: 0.6078
# 58/172, Train_loss: 0.3428
# Train_dice: 0.6572
# 59/172, Train_loss: 0.4486
# Train_dice: 0.5514
# 60/172, Train_loss: 0.2968
# Train_dice: 0.7032
# 61/172, Train_loss: 0.5291
# Train_dice: 0.4709
# 62/172, Train_loss: 0.3096
# Train_dice: 0.6904
# 63/172, Train_loss: 0.3192
# Train_dice: 0.6808
# 64/172, Train_loss: 0.4290
# Train_dice: 0.5710
# 65/172, Train_loss: 0.5170
# Train_dice: 0.4830
# 66/172, Train_loss: 0.3022
# Train_dice: 0.6978
# 67/172, Train_loss: 0.5064
# Train_dice: 0.4936
# 68/172, Train_loss: 0.4788
# Train_dice: 0.5212
# 69/172, Train_loss: 0.2923
# Train_dice: 0.7077
# 70/172, Train_loss: 0.3471
# Train_dice: 0.6529
# 71/172, Train_loss: 0.3004
# Train_dice: 0.6996
# 72/172, Train_loss: 0.4021
# Train_dice: 0.5979
# 73/172, Train_loss: 0.4219
# Train_dice: 0.5781
# 74/172, Train_loss: 0.4820
# Train_dice: 0.5180
# 75/172, Train_loss: 0.5474
# Train_dice: 0.4526
# 76/172, Train_loss: 0.2846
# Train_dice: 0.7154
# 77/172, Train_loss: 0.3539
# Train_dice: 0.6461
# 78/172, Train_loss: 0.4433
# Train_dice: 0.5567
# 79/172, Train_loss: 0.3399
# Train_dice: 0.6601
# 80/172, Train_loss: 0.5020
# Train_dice: 0.4980
# 81/172, Train_loss: 0.2763
# Train_dice: 0.7237
# 82/172, Train_loss: 0.2509
# Train_dice: 0.7491
# 83/172, Train_loss: 0.3890
# Train_dice: 0.6110
# 84/172, Train_loss: 0.5572
# Train_dice: 0.4428
# 85/172, Train_loss: 0.5471
# Train_dice: 0.4529
# 86/172, Train_loss: 0.5316
# Train_dice: 0.4684
# 87/172, Train_loss: 0.5621
# Train_dice: 0.4379
# 88/172, Train_loss: 0.5315
# Train_dice: 0.4685
# 89/172, Train_loss: 0.5368
# Train_dice: 0.4632
# 90/172, Train_loss: 0.3133
# Train_dice: 0.6867
# 91/172, Train_loss: 0.3998
# Train_dice: 0.6002
# 92/172, Train_loss: 0.4894
# Train_dice: 0.5106
# 93/172, Train_loss: 0.3572
# Train_dice: 0.6428
# 94/172, Train_loss: 0.5633
# Train_dice: 0.4367
# 95/172, Train_loss: 0.4340
# Train_dice: 0.5660
# 96/172, Train_loss: 0.3521
# Train_dice: 0.6479
# 97/172, Train_loss: 0.5052
# Train_dice: 0.4948
# 98/172, Train_loss: 0.5516
# Train_dice: 0.4484
# 99/172, Train_loss: 0.4004
# Train_dice: 0.5996
# 100/172, Train_loss: 0.2700
# Train_dice: 0.7300
# 101/172, Train_loss: 0.4686
# Train_dice: 0.5314
# 102/172, Train_loss: 0.4409
# Train_dice: 0.5591
# 103/172, Train_loss: 0.4259
# Train_dice: 0.5741
# 104/172, Train_loss: 0.4325
# Train_dice: 0.5675
# 105/172, Train_loss: 0.4338
# Train_dice: 0.5662
# 106/172, Train_loss: 0.4286
# Train_dice: 0.5714
# 107/172, Train_loss: 0.3029
# Train_dice: 0.6971
# 108/172, Train_loss: 0.5665
# Train_dice: 0.4335
# 109/172, Train_loss: 0.4253
# Train_dice: 0.5747
# 110/172, Train_loss: 0.5414
# Train_dice: 0.4586
# 111/172, Train_loss: 0.4541
# Train_dice: 0.5459
# 112/172, Train_loss: 0.3175
# Train_dice: 0.6825
# 113/172, Train_loss: 0.4231
# Train_dice: 0.5769
# 114/172, Train_loss: 0.3274
# Train_dice: 0.6726
# 115/172, Train_loss: 0.4069
# Train_dice: 0.5931
# 116/172, Train_loss: 0.2952
# Train_dice: 0.7048
# 117/172, Train_loss: 0.3519
# Train_dice: 0.6481
# 118/172, Train_loss: 0.2144
# Train_dice: 0.7856
# 119/172, Train_loss: 0.3333
# Train_dice: 0.6667
# 120/172, Train_loss: 0.3263
# Train_dice: 0.6737
# 121/172, Train_loss: 0.3298
# Train_dice: 0.6702
# 122/172, Train_loss: 0.5145
# Train_dice: 0.4855
# 123/172, Train_loss: 0.3601
# Train_dice: 0.6399
# 124/172, Train_loss: 0.2496
# Train_dice: 0.7504
# 125/172, Train_loss: 0.3616
# Train_dice: 0.6384
# 126/172, Train_loss: 0.5140
# Train_dice: 0.4860
# 127/172, Train_loss: 0.3336
# Train_dice: 0.6664
# 128/172, Train_loss: 0.2530
# Train_dice: 0.7470
# 129/172, Train_loss: 0.3922
# Train_dice: 0.6078
# 130/172, Train_loss: 0.2931
# Train_dice: 0.7069
# 131/172, Train_loss: 0.5115
# Train_dice: 0.4885
# 132/172, Train_loss: 0.4435
# Train_dice: 0.5565
# 133/172, Train_loss: 0.3040
# Train_dice: 0.6960
# 134/172, Train_loss: 0.4563
# Train_dice: 0.5437
# 135/172, Train_loss: 0.2740
# Train_dice: 0.7260
# 136/172, Train_loss: 0.4535
# Train_dice: 0.5465
# 137/172, Train_loss: 0.4533
# Train_dice: 0.5467
# 138/172, Train_loss: 0.2977
# Train_dice: 0.7023
# 139/172, Train_loss: 0.4373
# Train_dice: 0.5627
# 140/172, Train_loss: 0.3920
# Train_dice: 0.6080
# 141/172, Train_loss: 0.4712
# Train_dice: 0.5288
# 142/172, Train_loss: 0.5240
# Train_dice: 0.4760
# 143/172, Train_loss: 0.3034
# Train_dice: 0.6966
# 144/172, Train_loss: 0.3692
# Train_dice: 0.6308
# 145/172, Train_loss: 0.2641
# Train_dice: 0.7359
# 146/172, Train_loss: 0.5488
# Train_dice: 0.4512
# 147/172, Train_loss: 0.2980
# Train_dice: 0.7020
# 148/172, Train_loss: 0.2594
# Train_dice: 0.7406
# 149/172, Train_loss: 0.4592
# Train_dice: 0.5408
# 150/172, Train_loss: 0.5533
# Train_dice: 0.4467
# 151/172, Train_loss: 0.4480
# Train_dice: 0.5520
# 152/172, Train_loss: 0.3184
# Train_dice: 0.6816
# ...
# Train_dice: 0.9844
# 11/172, Train_loss: 0.0294
# Train_dice: 0.9706
# 12/172, Train_loss: 0.0152
# Train_dice: 0.9848
# 13/172, Train_loss: 0.0481
# Train_dice: 0.9519
# 14/172, Train_loss: 0.0127
# Train_dice: 0.9873
# 15/172, Train_loss: 0.0138
# Train_dice: 0.9862
# 16/172, Train_loss: 0.0665
# Train_dice: 0.9335
# 17/172, Train_loss: 0.0147
# Train_dice: 0.9853
# 18/172, Train_loss: 0.0256
# Train_dice: 0.9744
# 19/172, Train_loss: 0.0112
# Train_dice: 0.9888
# 20/172, Train_loss: 0.0232
# Train_dice: 0.9768
# 21/172, Train_loss: 0.2068
# Train_dice: 0.7932
# 22/172, Train_loss: 0.0098
# Train_dice: 0.9902
# 23/172, Train_loss: 0.0156
# Train_dice: 0.9844
# 24/172, Train_loss: 0.1132
# Train_dice: 0.8868
# 25/172, Train_loss: 0.0876
# Train_dice: 0.9124
# 26/172, Train_loss: 0.0134
# Train_dice: 0.9866
# 27/172, Train_loss: 0.0228
# Train_dice: 0.9772
# 28/172, Train_loss: 0.1933
# Train_dice: 0.8067
# 29/172, Train_loss: 0.0844
# Train_dice: 0.9156
# 30/172, Train_loss: 0.0094
# Train_dice: 0.9906
# 31/172, Train_loss: 0.0210
# Train_dice: 0.9790
# 32/172, Train_loss: 0.2109
# Train_dice: 0.7891
# 33/172, Train_loss: 0.0447
# Train_dice: 0.9553
# 34/172, Train_loss: 0.0546
# Train_dice: 0.9454
# 35/172, Train_loss: 0.0107
# Train_dice: 0.9893
# 36/172, Train_loss: 0.0209
# Train_dice: 0.9791
# 37/172, Train_loss: 0.0137
# Train_dice: 0.9863
# 38/172, Train_loss: 0.0159
# Train_dice: 0.9841
# 39/172, Train_loss: 0.0825
# Train_dice: 0.9175
# 40/172, Train_loss: 0.0145
# Train_dice: 0.9855
# 41/172, Train_loss: 0.0196
# Train_dice: 0.9804
# 42/172, Train_loss: 0.0182
# Train_dice: 0.9818
# 43/172, Train_loss: 0.0293
# Train_dice: 0.9707
# 44/172, Train_loss: 0.0249
# Train_dice: 0.9751
# 45/172, Train_loss: 0.1512
# Train_dice: 0.8488
# 46/172, Train_loss: 0.0411
# Train_dice: 0.9589
# 47/172, Train_loss: 0.0134
# Train_dice: 0.9866
# 48/172, Train_loss: 0.0301
# Train_dice: 0.9699
# 49/172, Train_loss: 0.1506
# Train_dice: 0.8494
# 50/172, Train_loss: 0.0115
# Train_dice: 0.9885
# 51/172, Train_loss: 0.0158
# Train_dice: 0.9842
# 52/172, Train_loss: 0.0435
# Train_dice: 0.9565
# 53/172, Train_loss: 0.0120
# Train_dice: 0.9880
# 54/172, Train_loss: 0.0164
# Train_dice: 0.9836
# 55/172, Train_loss: 0.0725
# Train_dice: 0.9275
# 56/172, Train_loss: 0.0118
# Train_dice: 0.9882
# 57/172, Train_loss: 0.0203
# Train_dice: 0.9797
# 58/172, Train_loss: 0.0141
# Train_dice: 0.9859
# 59/172, Train_loss: 0.0369
# Train_dice: 0.9631
# 60/172, Train_loss: 0.0132
# Train_dice: 0.9868
# 61/172, Train_loss: 0.0886
# Train_dice: 0.9114
# 62/172, Train_loss: 0.0136
# Train_dice: 0.9864
# 63/172, Train_loss: 0.0155
# Train_dice: 0.9845
# 64/172, Train_loss: 0.0306
# Train_dice: 0.9694
# 65/172, Train_loss: 0.0663
# Train_dice: 0.9337
# 66/172, Train_loss: 0.0131
# Train_dice: 0.9869
# 67/172, Train_loss: 0.0601
# Train_dice: 0.9399
# 68/172, Train_loss: 0.0439
# Train_dice: 0.9561
# 69/172, Train_loss: 0.0119
# Train_dice: 0.9881
# 70/172, Train_loss: 0.0151
# Train_dice: 0.9849
# 71/172, Train_loss: 0.0147
# Train_dice: 0.9853
# 72/172, Train_loss: 0.0242
# Train_dice: 0.9758
# 73/172, Train_loss: 0.0316
# Train_dice: 0.9684
# 74/172, Train_loss: 0.0485
# Train_dice: 0.9515
# 75/172, Train_loss: 0.1283
# Train_dice: 0.8717
# 76/172, Train_loss: 0.0121
# Train_dice: 0.9879
# 77/172, Train_loss: 0.0185
# Train_dice: 0.9815
# 78/172, Train_loss: 0.0357
# Train_dice: 0.9643
# 79/172, Train_loss: 0.0164
# Train_dice: 0.9836
# 80/172, Train_loss: 0.0486
# Train_dice: 0.9514
# 81/172, Train_loss: 0.0107
# Train_dice: 0.9893
# 82/172, Train_loss: 0.0103
# Train_dice: 0.9897
# 83/172, Train_loss: 0.0220
# Train_dice: 0.9780
# 84/172, Train_loss: 0.1771
# Train_dice: 0.8229
# 85/172, Train_loss: 0.1207
# Train_dice: 0.8793
# 86/172, Train_loss: 0.0682
# Train_dice: 0.9318
# 87/172, Train_loss: 0.1402
# Train_dice: 0.8598
# 88/172, Train_loss: 0.0688
# Train_dice: 0.9312
# 89/172, Train_loss: 0.1043
# Train_dice: 0.8957
# 90/172, Train_loss: 0.0167
# Train_dice: 0.9833
# 91/172, Train_loss: 0.0253
# Train_dice: 0.9747
# 92/172, Train_loss: 0.0537
# Train_dice: 0.9463
# 93/172, Train_loss: 0.0169
# Train_dice: 0.9831
# 94/172, Train_loss: 0.2121
# Train_dice: 0.7879
# 95/172, Train_loss: 0.0298
# Train_dice: 0.9702
# 96/172, Train_loss: 0.0209
# Train_dice: 0.9791
# 97/172, Train_loss: 0.0624
# Train_dice: 0.9376
# 98/172, Train_loss: 0.1481
# Train_dice: 0.8519
# 99/172, Train_loss: 0.0246
# Train_dice: 0.9754
# 100/172, Train_loss: 0.0103
# Train_dice: 0.9897
# 101/172, Train_loss: 0.0433
# Train_dice: 0.9567
# 102/172, Train_loss: 0.0315
# Train_dice: 0.9685
# 103/172, Train_loss: 0.0273
# Train_dice: 0.9727
# 104/172, Train_loss: 0.0304
# Train_dice: 0.9696
# 105/172, Train_loss: 0.0285
# Train_dice: 0.9715
# 106/172, Train_loss: 0.0284
# Train_dice: 0.9716
# 107/172, Train_loss: 0.0129
# Train_dice: 0.9871
# 108/172, Train_loss: 0.2415
# Train_dice: 0.7585
# 109/172, Train_loss: 0.0283
# Train_dice: 0.9717
# 110/172, Train_loss: 0.1171
# Train_dice: 0.8829
# 111/172, Train_loss: 0.0381
# Train_dice: 0.9619
# 112/172, Train_loss: 0.0147
# Train_dice: 0.9853
# 113/172, Train_loss: 0.0262
# Train_dice: 0.9738
# 114/172, Train_loss: 0.0145
# Train_dice: 0.9855
# 115/172, Train_loss: 0.0237
# Train_dice: 0.9763
# 116/172, Train_loss: 0.0106
# Train_dice: 0.9894
# 117/172, Train_loss: 0.0173
# Train_dice: 0.9827
# 118/172, Train_loss: 0.0106
# Train_dice: 0.9894
# 119/172, Train_loss: 0.0137
# Train_dice: 0.9863
# 120/172, Train_loss: 0.0155
# Train_dice: 0.9845
# 121/172, Train_loss: 0.0139
# Train_dice: 0.9861
# 122/172, Train_loss: 0.0796
# Train_dice: 0.9204
# 123/172, Train_loss: 0.0177
# Train_dice: 0.9823
# 124/172, Train_loss: 0.0104
# Train_dice: 0.9896
# 125/172, Train_loss: 0.0172
# Train_dice: 0.9828
# 126/172, Train_loss: 0.0765
# Train_dice: 0.9235
# 127/172, Train_loss: 0.0150
# Train_dice: 0.9850
# 128/172, Train_loss: 0.0100
# Train_dice: 0.9900
# 129/172, Train_loss: 0.0203
# Train_dice: 0.9797
# 130/172, Train_loss: 0.0125
# Train_dice: 0.9875
# 131/172, Train_loss: 0.0767
# Train_dice: 0.9233
# 132/172, Train_loss: 0.0355
# Train_dice: 0.9645
# 133/172, Train_loss: 0.0124
# Train_dice: 0.9876
# 134/172, Train_loss: 0.0391
# Train_dice: 0.9609
# 135/172, Train_loss: 0.0133
# Train_dice: 0.9867
# 136/172, Train_loss: 0.0358
# Train_dice: 0.9642
# 137/172, Train_loss: 0.0353
# Train_dice: 0.9647
# 138/172, Train_loss: 0.0135
# Train_dice: 0.9865
# 139/172, Train_loss: 0.0318
# Train_dice: 0.9682
# 140/172, Train_loss: 0.0233
# Train_dice: 0.9767
# 141/172, Train_loss: 0.0421
# Train_dice: 0.9579
# 142/172, Train_loss: 0.0935
# Train_dice: 0.9065
# 143/172, Train_loss: 0.0127
# Train_dice: 0.9873
# 144/172, Train_loss: 0.0212
# Train_dice: 0.9788
# 145/172, Train_loss: 0.0117
# Train_dice: 0.9883
# 146/172, Train_loss: 0.1504
# Train_dice: 0.8496
# 147/172, Train_loss: 0.0129
# Train_dice: 0.9871
# 148/172, Train_loss: 0.0103
# Train_dice: 0.9897
# 149/172, Train_loss: 0.0402
# Train_dice: 0.9598
# 150/172, Train_loss: 0.1735
# Train_dice: 0.8265
# 151/172, Train_loss: 0.0378
# Train_dice: 0.9622
# 152/172, Train_loss: 0.0150
# Train_dice: 0.9850
# 153/172, Train_loss: 0.0210
# Train_dice: 0.9790
# 154/172, Train_loss: 0.1861
# Train_dice: 0.8139
# 155/172, Train_loss: 0.0399
# Train_dice: 0.9601
# 156/172, Train_loss: 0.0113
# Train_dice: 0.9887
# 157/172, Train_loss: 0.0322
# Train_dice: 0.9678
# 158/172, Train_loss: 0.1732
# Train_dice: 0.8268
# 159/172, Train_loss: 0.0347
# Train_dice: 0.9653
# 160/172, Train_loss: 0.0164
# Train_dice: 0.9836
# 161/172, Train_loss: 0.0105
# Train_dice: 0.9895
# 162/172, Train_loss: 0.0130
# Train_dice: 0.9870
# 163/172, Train_loss: 0.1256
# Train_dice: 0.8744
# 164/172, Train_loss: 0.0192
# Train_dice: 0.9808
# 165/172, Train_loss: 0.0115
# Train_dice: 0.9885
# 166/172, Train_loss: 0.0184
# Train_dice: 0.9816
# 167/172, Train_loss: 0.0199
# Train_dice: 0.9801
# 168/172, Train_loss: 0.0099
# Train_dice: 0.9901
# 169/172, Train_loss: 0.0348
# Train_dice: 0.9652
# 170/172, Train_loss: 0.0113
# Train_dice: 0.9887
# 171/172, Train_loss: 0.0403
# Train_dice: 0.9597
# 172/172, Train_loss: 0.0158
# Train_dice: 0.9842
# --------------------
# Epoch_loss: 0.0432
# Epoch_metric: 0.9568
# test_loss_epoch: 0.0989
# test_dice_epoch: 0.9011
# current epoch: 119 current mean dice: 0.9302
# best mean dice: 0.9012 at epoch: 116
# ----------
# epoch 120/120
# 1/172, Train_loss: 0.0354
# Train_dice: 0.9646
# 2/172, Train_loss: 0.0134
# Train_dice: 0.9866
# 3/172, Train_loss: 0.0095
# Train_dice: 0.9905
# 4/172, Train_loss: 0.0464
# Train_dice: 0.9536
# 5/172, Train_loss: 0.0129
# Train_dice: 0.9871
# 6/172, Train_loss: 0.0087
# Train_dice: 0.9913
# 7/172, Train_loss: 0.0163
# Train_dice: 0.9837
# 8/172, Train_loss: 0.0741
# Train_dice: 0.9259
# 9/172, Train_loss: 0.0272
# Train_dice: 0.9728
# 10/172, Train_loss: 0.0152
# Train_dice: 0.9848
# 11/172, Train_loss: 0.0286
# Train_dice: 0.9714
# 12/172, Train_loss: 0.0149
# Train_dice: 0.9851
# 13/172, Train_loss: 0.0463
# Train_dice: 0.9537
# 14/172, Train_loss: 0.0126
# Train_dice: 0.9874
# 15/172, Train_loss: 0.0139
# Train_dice: 0.9861
# 16/172, Train_loss: 0.0653
# Train_dice: 0.9347
# 17/172, Train_loss: 0.0148
# Train_dice: 0.9852
# 18/172, Train_loss: 0.0255
# Train_dice: 0.9745
# 19/172, Train_loss: 0.0114
# Train_dice: 0.9886
# 20/172, Train_loss: 0.0229
# Train_dice: 0.9771
# 21/172, Train_loss: 0.2029
# Train_dice: 0.7971
# 22/172, Train_loss: 0.0102
# Train_dice: 0.9898
# 23/172, Train_loss: 0.0158
# Train_dice: 0.9842
# 24/172, Train_loss: 0.1116
# Train_dice: 0.8884
# 25/172, Train_loss: 0.0856
# Train_dice: 0.9144
# 26/172, Train_loss: 0.0134
# Train_dice: 0.9866
# 27/172, Train_loss: 0.0223
# Train_dice: 0.9777
# 28/172, Train_loss: 0.1894
# Train_dice: 0.8106
# 29/172, Train_loss: 0.0824
# Train_dice: 0.9176
# 30/172, Train_loss: 0.0093
# Train_dice: 0.9907
# 31/172, Train_loss: 0.0204
# Train_dice: 0.9796
# 32/172, Train_loss: 0.2080
# Train_dice: 0.7920
# 33/172, Train_loss: 0.0437
# Train_dice: 0.9563
# 34/172, Train_loss: 0.0536
# Train_dice: 0.9464
# 35/172, Train_loss: 0.0105
# Train_dice: 0.9895
# 36/172, Train_loss: 0.0206
# Train_dice: 0.9794
# 37/172, Train_loss: 0.0133
# Train_dice: 0.9867
# 38/172, Train_loss: 0.0158
# Train_dice: 0.9842
# 39/172, Train_loss: 0.0809
# Train_dice: 0.9191
# 40/172, Train_loss: 0.0141
# Train_dice: 0.9859
# 41/172, Train_loss: 0.0191
# Train_dice: 0.9809
# 42/172, Train_loss: 0.0177
# Train_dice: 0.9823
# 43/172, Train_loss: 0.0287
# Train_dice: 0.9713
# 44/172, Train_loss: 0.0242
# Train_dice: 0.9758
# 45/172, Train_loss: 0.1486
# Train_dice: 0.8514
# 46/172, Train_loss: 0.0401
# Train_dice: 0.9599
# 47/172, Train_loss: 0.0130
# Train_dice: 0.9870
# 48/172, Train_loss: 0.0293
# Train_dice: 0.9707
# 49/172, Train_loss: 0.1477
# Train_dice: 0.8523
# 50/172, Train_loss: 0.0113
# Train_dice: 0.9887
# 51/172, Train_loss: 0.0156
# Train_dice: 0.9844
# 52/172, Train_loss: 0.0426
# Train_dice: 0.9574
# 53/172, Train_loss: 0.0115
# Train_dice: 0.9885
# 54/172, Train_loss: 0.0159
# Train_dice: 0.9841
# 55/172, Train_loss: 0.0702
# Train_dice: 0.9298
# 56/172, Train_loss: 0.0117
# Train_dice: 0.9883
# 57/172, Train_loss: 0.0198
# Train_dice: 0.9802
# 58/172, Train_loss: 0.0139
# Train_dice: 0.9861
# 59/172, Train_loss: 0.0364
# Train_dice: 0.9636
# 60/172, Train_loss: 0.0131
# Train_dice: 0.9869
# 61/172, Train_loss: 0.0864
# Train_dice: 0.9136
# 62/172, Train_loss: 0.0132
# Train_dice: 0.9868
# 63/172, Train_loss: 0.0149
# Train_dice: 0.9851
# 64/172, Train_loss: 0.0297
# Train_dice: 0.9703
# 65/172, Train_loss: 0.0644
# Train_dice: 0.9356
# 66/172, Train_loss: 0.0128
# Train_dice: 0.9872
# 67/172, Train_loss: 0.0588
# Train_dice: 0.9412
# 68/172, Train_loss: 0.0434
# Train_dice: 0.9566
# 69/172, Train_loss: 0.0117
# Train_dice: 0.9883
# 70/172, Train_loss: 0.0144
# Train_dice: 0.9856
# 71/172, Train_loss: 0.0142
# Train_dice: 0.9858
# 72/172, Train_loss: 0.0238
# Train_dice: 0.9762
# 73/172, Train_loss: 0.0315
# Train_dice: 0.9685
# 74/172, Train_loss: 0.0479
# Train_dice: 0.9521
# 75/172, Train_loss: 0.1261
# Train_dice: 0.8739
# 76/172, Train_loss: 0.0118
# Train_dice: 0.9882
# 77/172, Train_loss: 0.0184
# Train_dice: 0.9816
# 78/172, Train_loss: 0.0354
# Train_dice: 0.9646
# 79/172, Train_loss: 0.0155
# Train_dice: 0.9845
# 80/172, Train_loss: 0.0473
# Train_dice: 0.9527
# 81/172, Train_loss: 0.0103
# Train_dice: 0.9897
# 82/172, Train_loss: 0.0104
# Train_dice: 0.9896
# 83/172, Train_loss: 0.0216
# Train_dice: 0.9784
# 84/172, Train_loss: 0.1739
# Train_dice: 0.8261
# 85/172, Train_loss: 0.1267
# Train_dice: 0.8733
# 86/172, Train_loss: 0.0668
# Train_dice: 0.9332
# 87/172, Train_loss: 0.1434
# Train_dice: 0.8566
# 88/172, Train_loss: 0.0678
# Train_dice: 0.9322
# 89/172, Train_loss: 0.1019
# Train_dice: 0.8981
# 90/172, Train_loss: 0.0162
# Train_dice: 0.9838
# 91/172, Train_loss: 0.0251
# Train_dice: 0.9749
# 92/172, Train_loss: 0.0529
# Train_dice: 0.9471
# 93/172, Train_loss: 0.0169
# Train_dice: 0.9831
# 94/172, Train_loss: 0.2089
# Train_dice: 0.7911
# 95/172, Train_loss: 0.0295
# Train_dice: 0.9705
# 96/172, Train_loss: 0.0207
# Train_dice: 0.9793
# 97/172, Train_loss: 0.0612
# Train_dice: 0.9388
# 98/172, Train_loss: 0.1453
# Train_dice: 0.8547
# 99/172, Train_loss: 0.0238
# Train_dice: 0.9762
# 100/172, Train_loss: 0.0102
# Train_dice: 0.9898
# 101/172, Train_loss: 0.0420
# Train_dice: 0.9580
# 102/172, Train_loss: 0.0307
# Train_dice: 0.9693
# 103/172, Train_loss: 0.0268
# Train_dice: 0.9732
# 104/172, Train_loss: 0.0295
# Train_dice: 0.9705
# 105/172, Train_loss: 0.0278
# Train_dice: 0.9722
# 106/172, Train_loss: 0.0277
# Train_dice: 0.9723
# 107/172, Train_loss: 0.0126
# Train_dice: 0.9874
# 108/172, Train_loss: 0.2393
# Train_dice: 0.7607
# 109/172, Train_loss: 0.0276
# Train_dice: 0.9724
# 110/172, Train_loss: 0.1149
# Train_dice: 0.8851
# 111/172, Train_loss: 0.0371
# Train_dice: 0.9629
# 112/172, Train_loss: 0.0141
# Train_dice: 0.9859
# 113/172, Train_loss: 0.0252
# Train_dice: 0.9748
# 114/172, Train_loss: 0.0134
# Train_dice: 0.9866
# 115/172, Train_loss: 0.0224
# Train_dice: 0.9776
# 116/172, Train_loss: 0.0103
# Train_dice: 0.9897
# 117/172, Train_loss: 0.0166
# Train_dice: 0.9834
# 118/172, Train_loss: 0.0101
# Train_dice: 0.9899
# 119/172, Train_loss: 0.0133
# Train_dice: 0.9867
# 120/172, Train_loss: 0.0150
# Train_dice: 0.9850
# 121/172, Train_loss: 0.0136
# Train_dice: 0.9864
# 122/172, Train_loss: 0.0775
# Train_dice: 0.9225
# 123/172, Train_loss: 0.0174
# Train_dice: 0.9826
# 124/172, Train_loss: 0.0102
# Train_dice: 0.9898
# 125/172, Train_loss: 0.0168
# Train_dice: 0.9832
# 126/172, Train_loss: 0.0747
# Train_dice: 0.9253
# 127/172, Train_loss: 0.0144
# Train_dice: 0.9856
# 128/172, Train_loss: 0.0097
# Train_dice: 0.9903
# 129/172, Train_loss: 0.0201
# Train_dice: 0.9799
# 130/172, Train_loss: 0.0120
# Train_dice: 0.9880
# 131/172, Train_loss: 0.0749
# Train_dice: 0.9251
# 132/172, Train_loss: 0.0343
# Train_dice: 0.9657
# 133/172, Train_loss: 0.0121
# Train_dice: 0.9879
# 134/172, Train_loss: 0.0380
# Train_dice: 0.9620
# 135/172, Train_loss: 0.0127
# Train_dice: 0.9873
# 136/172, Train_loss: 0.0349
# Train_dice: 0.9651
# 137/172, Train_loss: 0.0343
# Train_dice: 0.9657
# 138/172, Train_loss: 0.0130
# Train_dice: 0.9870
# 139/172, Train_loss: 0.0306
# Train_dice: 0.9694
# 140/172, Train_loss: 0.0221
# Train_dice: 0.9779
# 141/172, Train_loss: 0.0408
# Train_dice: 0.9592
# 142/172, Train_loss: 0.0912
# Train_dice: 0.9088
# 143/172, Train_loss: 0.0125
# Train_dice: 0.9875
# 144/172, Train_loss: 0.0205
# Train_dice: 0.9795
# 145/172, Train_loss: 0.0116
# Train_dice: 0.9884
# 146/172, Train_loss: 0.1473
# Train_dice: 0.8527
# 147/172, Train_loss: 0.0128
# Train_dice: 0.9872
# 148/172, Train_loss: 0.0102
# Train_dice: 0.9898
# 149/172, Train_loss: 0.0395
# Train_dice: 0.9605
# 150/172, Train_loss: 0.1706
# Train_dice: 0.8294
# 151/172, Train_loss: 0.0372
# Train_dice: 0.9628
# 152/172, Train_loss: 0.0149
# Train_dice: 0.9851
# 153/172, Train_loss: 0.0208
# Train_dice: 0.9792
# 154/172, Train_loss: 0.1831
# Train_dice: 0.8169
# 155/172, Train_loss: 0.0390
# Train_dice: 0.9610
# 156/172, Train_loss: 0.0110
# Train_dice: 0.9890
# 157/172, Train_loss: 0.0313
# Train_dice: 0.9687
# 158/172, Train_loss: 0.1695
# Train_dice: 0.8305
# 159/172, Train_loss: 0.0341
# Train_dice: 0.9659
# 160/172, Train_loss: 0.0159
# Train_dice: 0.9841
# 161/172, Train_loss: 0.0102
# Train_dice: 0.9898
# 162/172, Train_loss: 0.0127
# Train_dice: 0.9873
# 163/172, Train_loss: 0.1230
# Train_dice: 0.8770
# 164/172, Train_loss: 0.0186
# Train_dice: 0.9814
# 165/172, Train_loss: 0.0110
# Train_dice: 0.9890
# 166/172, Train_loss: 0.0181
# Train_dice: 0.9819
# 167/172, Train_loss: 0.0196
# Train_dice: 0.9804
# 168/172, Train_loss: 0.0100
# Train_dice: 0.9900
# 169/172, Train_loss: 0.0342
# Train_dice: 0.9658
# 170/172, Train_loss: 0.0119
# Train_dice: 0.9881
# 171/172, Train_loss: 0.0402
# Train_dice: 0.9598
# 172/172, Train_loss: 0.0159
# Train_dice: 0.9841
# --------------------
# Epoch_loss: 0.0424
# Epoch_metric: 0.9576
# test_loss_epoch: 0.1001
# test_dice_epoch: 0.8999
# current epoch: 120 current mean dice: 0.9277
# best mean dice: 0.9012 at epoch: 116
# train completed, best_metric: 0.9012 at epoch: 116
