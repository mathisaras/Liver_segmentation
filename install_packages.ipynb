# %%
#!pip install monai
# Out:
# ...
#   Using cached monai-1.3.2-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached torch-2.4.1-cp38-cp38-win_amd64.whl.metadata (27 kB)
# ...
#   Using cached filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# ...
# Using cached monai-1.3.2-py3-none-any.whl (1.4 MB)
# Using cached torch-2.4.1-cp38-cp38-win_amd64.whl (199.4 MB)
# Using cached filelock-3.16.1-py3-none-any.whl (16 kB)
# Using cached fsspec-2024.12.0-py3-none-any.whl (183 kB)
# ...

# %%
#!pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
#      ---------------------------------------- 0.0/5.0 MB ? eta -:--:--
#      ---- ----------------------------------- 0.5/5.0 MB 5.7 MB/s eta 0:00:01
#      ------------ --------------------------- 1.6/5.0 MB 5.2 MB/s eta 0:00:01
#      ---------------------- ----------------- 2.9/5.0 MB 5.8 MB/s eta 0:00:01
#      ----------------------------- ---------- 3.7/5.0 MB 5.2 MB/s eta 0:00:01
#      ------------------------------------- -- 4.7/5.0 MB 5.2 MB/s eta 0:00:01
#      ---------------------------------------  5.0/5.0 MB 4.4 MB/s eta 0:00:01
#      ---------------------------------------- 5.0/5.0 MB 4.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#      ----- ---------------------------------- 0.5/4.0 MB 2.4 MB/s eta 0:00:02
#      ---------- ----------------------------- 1.0/4.0 MB 3.0 MB/s eta 0:00:02
# ...

# %%
#pip install tqdm
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
